# %% [markdown]
# # Pandas

# %% [markdown]
# Материалы:
# * Макрушин С.В. "Лекция 2: Библиотека Pandas"
# * https://pandas.pydata.org/docs/user_guide/index.html#
# * https://pandas.pydata.org/docs/reference/index.html
# * Уэс Маккини. Python и анализ данных

# %% [markdown]
# ## Задачи для совместного разбора

# %%
# атрибут loc позволяет выполнить индексацию и срезы с использованием явного индекса
# атрибут iloc дает возможность выполнить индексацию и срезы, применяя неявный индекс в стиле языка Python

# %% [markdown]
# 1. Загрузите данные из файла `sp500hst.txt` и обозначьте столбцы в соответствии с содержимым: `"date", "ticker", "open", "high", "low", "close", "volume"`.

# %%
import pandas as pd
name_columns = ["date", "ticker", "open", "high","low", "close", "volume"]
my_data = pd.read_csv("sp500hst.txt", sep=',',
                 names = name_columns)

#my_data[["open","close"]].head(5)
print(my_data)
# Out:
#             date ticker   open     high     low  close  volume
# 0       20090821      A  25.60  25.6100  25.220  25.55   34758
# 1       20090824      A  25.64  25.7400  25.330  25.50   22247
# 2       20090825      A  25.50  25.7000  25.225  25.34   30891
# 3       20090826      A  25.32  25.6425  25.145  25.48   33334
# 4       20090827      A  25.50  25.5700  25.230  25.54   70176
# ...          ...    ...    ...      ...     ...    ...     ...
# 122569  20100813    ZMH  51.72  51.9000  51.380  51.44   14561
# 122570  20100816    ZMH  51.13  51.4700  50.600  51.00   13489
# 122571  20100817    ZMH  51.14  51.6000  50.890  51.21   20498
# 122572  20100819    ZMH  51.63  51.6300  50.170  50.22   18259
# 122573  20100820    ZMH  50.03  50.5500  49.480  49.82   17792
#
# [122574 rows x 7 columns]

# %% [markdown]
# 2. Рассчитайте среднее значение показателей для каждого из столбцов c номерами 3-6.

# %%
print(my_data.loc[:, "high":"volume"].mean())
new_data = my_data.iloc[:, 3:7].mean()
new_data
# Out:
# high         43.102243
# low          42.054464
# close        42.601865
# volume    81395.068138
# dtype: float64
# high         43.102243
# low          42.054464
# close        42.601865
# volume    81395.068138
# dtype: float64

# %% [markdown]
# 3. Добавьте столбец, содержащий только число месяца, к которому относится дата.

# %%
my_data['date'] = pd.to_datetime(my_data['date'], format='%Y%m%d')
my_data['month'] = my_data['date'].dt.month
#то, что ниже - просто для прикола
my_data['day'] = my_data['date'].dt.day
my_data['year'] = my_data['date'].dt.year
my_data
# Out:
#              date ticker   open     high     low  close  volume  month  day  \
# 0      2009-08-21      A  25.60  25.6100  25.220  25.55   34758      8   21
# 1      2009-08-24      A  25.64  25.7400  25.330  25.50   22247      8   24
# 2      2009-08-25      A  25.50  25.7000  25.225  25.34   30891      8   25
# 3      2009-08-26      A  25.32  25.6425  25.145  25.48   33334      8   26
# 4      2009-08-27      A  25.50  25.5700  25.230  25.54   70176      8   27
# ...           ...    ...    ...      ...     ...    ...     ...    ...  ...
# 122569 2010-08-13    ZMH  51.72  51.9000  51.380  51.44   14561      8   13
# 122570 2010-08-16    ZMH  51.13  51.4700  50.600  51.00   13489      8   16
# 122571 2010-08-17    ZMH  51.14  51.6000  50.890  51.21   20498      8   17
# 122572 2010-08-19    ZMH  51.63  51.6300  50.170  50.22   18259      8   19
# 122573 2010-08-20    ZMH  50.03  50.5500  49.480  49.82   17792      8   20
#
#         year
# 0       2009
# 1       2009
# ...

# %% [markdown]
# 4. Рассчитайте суммарный объем торгов для для одинаковых значений тикеров.

# %%
my_data.groupby('ticker')['volume'].sum() #см ячейку 120 лекции
# Out:
# ticker
# A        8609336
# AA      81898998
# AAPL    52261170
# ABC      9006756
# ABT     18975870
#           ...
# XTO     21297931
# YHOO    56837171
# YUM     10971538
# ZION    15551119
# ZMH      4938916
# Name: volume, Length: 524, dtype: int64

# %% [markdown]
# 5. Загрузите данные из файла sp500hst.txt и обозначьте столбцы в соответствии с содержимым: "date", "ticker", "open", "high", "low", "close", "volume". Добавьте столбец с расшифровкой названия тикера, используя данные из файла `sp_data2.csv` . В случае нехватки данных об именах тикеров корректно обработать их.

# %%
my_new_data = pd.read_csv("sp_data2.csv", sep=";",names=["ticker","company_name", "%"])
my_new_data
my_data
pd.merge(my_data, my_new_data) #131 lec
# Out:
#             date ticker   open     high     low  close  volume  month  day  \
# 0     2009-08-21      A  25.60  25.6100  25.220  25.55   34758      8   21
# 1     2009-08-24      A  25.64  25.7400  25.330  25.50   22247      8   24
# 2     2009-08-25      A  25.50  25.7000  25.225  25.34   30891      8   25
# 3     2009-08-26      A  25.32  25.6425  25.145  25.48   33334      8   26
# 4     2009-08-27      A  25.50  25.5700  25.230  25.54   70176      8   27
# ...          ...    ...    ...      ...     ...    ...     ...    ...  ...
# 82167 2010-08-13   ZION  20.17  20.4300  19.840  19.89   25193      8   13
# 82168 2010-08-16   ZION  19.81  19.9600  19.600  19.95   25914      8   16
# 82169 2010-08-17   ZION  20.07  20.4700  19.830  20.31   31717      8   17
# 82170 2010-08-19   ZION  19.83  20.0000  19.130  19.35   45935      8   19
# 82171 2010-08-20   ZION  19.15  19.2700  18.810  19.14   37225      8   20
#
#        year          company_name     %
# ...

# %% [markdown]
# ## Лабораторная работа №2

# %% [markdown]
# ### Базовые операции с `DataFrame`

# %% [markdown]
# 1.1 В файлах `recipes_sample.csv` и `reviews_sample.csv` находится информация об рецептах блюд и отзывах на эти рецепты соответственно. Загрузите данные из файлов в виде `pd.DataFrame` с названиями `recipes` и `reviews`. Обратите внимание на корректное считывание столбца(ов) с индексами.

# %%
recipes = pd.read_csv("recipes_sample.csv", sep=',',parse_dates=["submitted"])
recipes
# Out:
#                                                name      id  minutes  \
# 0             george s at the cove  black bean soup   44123       90
# 1                healthy for them  yogurt popsicles   67664       10
# 2                      i can t believe it s spinach   38798       30
# 3                              italian  gut busters   35173       45
# 4          love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29995  zurie s holey rustic olive and cheddar bread  267661       80
# 29996          zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   zwiebelkuchen   southwest german onion cake  103312       75
# 29998                                   zydeco soup  486161       60
# 29999        cookies by design   cookies on a stick  298512       29
#
#        contributor_id  submitted  n_steps  \
# 0               35193 2002-10-25      NaN
# 1               91970 2003-07-26      NaN
# ...

# %%
reviews = pd.read_csv("reviews_sample.csv", sep=",", parse_dates=["date"])
print(reviews)
# Out:
#         Unnamed: 0     user_id  recipe_id       date  rating  \
# 0           370476       21752      57993 2003-05-01       5
# 1           624300      431813     142201 2007-09-16       5
# 2           187037      400708     252013 2008-01-10       4
# 3           706134  2001852463     404716 2017-12-11       5
# 4           312179       95810     129396 2008-03-14       5
# ...            ...         ...        ...        ...     ...
# 126691     1013457     1270706     335534 2009-05-17       4
# 126692      158736     2282344       8701 2012-06-03       0
# 126693     1059834      689540     222001 2008-04-08       5
# 126694      453285  2000242659     354979 2015-06-02       5
# 126695      691207      463435     415599 2010-09-30       5
#
#                                                    review
# 0       Last week whole sides of frozen salmon fillet ...
# 1       So simple and so tasty!  I used a yellow capsi...
# ...

# %% [markdown]
# 1.2 Для каждой из таблиц выведите основные параметры:
# * количество точек данных (строк);
# * количество столбцов;
# * тип данных каждого столбца.

# %%
kolvo_strok = len(recipes.index)
print("Количество точек данных (строк)", kolvo_strok)

kolvo_col = len(recipes.columns)
print("Количество столбцов", kolvo_col)

print(recipes.dtypes) # dtypes - тип данных каждого столбца
# Out:
# Количество точек данных (строк) 30000
# Количество столбцов 8
# name                      object
# id                         int64
# minutes                    int64
# contributor_id             int64
# submitted         datetime64[ns]
# n_steps                  float64
# description               object
# n_ingredients            float64
# dtype: object

# %%
kolvo_strok2 = len(reviews.index)
print("Количество точек данных (строк)", kolvo_strok2)

kolvo_col2 = len(reviews.columns)
print("Количество столбцов", kolvo_col2)

print(reviews.dtypes) # dtypes - тип данных каждого столбца
# Out:
# Количество точек данных (строк) 126696
# Количество столбцов 6
# Unnamed: 0             int64
# user_id                int64
# recipe_id              int64
# date          datetime64[ns]
# rating                 int64
# review                object
# dtype: object

# %% [markdown]
# 1.3 Исследуйте, в каких столбцах таблиц содержатся пропуски. Посчитайте долю строк, содержащих пропуски, в отношении к общему количеству строк.

# %%
mask = recipes.isnull()
#print(mask)
print("Кол-во пропусков в столбце: \n", mask.sum())

print()

all_col = len(recipes.index)
print("Все строки", all_col)

not_na_col = len(recipes.dropna()) #dropna - возвратит строки без na  (default - axis = 0 по строкам и how = "any")
print("Строки без na", not_na_col)

na_col = all_col - not_na_col
print("Строки с na", na_col)

dolya_na_col = na_col * 100 / all_col

print("Доля в отношении к общему кол-ву строк (для na): " , na_col * 100 / all_col, "%")
# Out:
# Кол-во пропусков в столбце:
#  name                  0
# id                    0
# minutes               0
# contributor_id        0
# submitted             0
# n_steps           11190
# description         623
# n_ingredients      8880
# dtype: int64
#
# Все строки 30000
# Строки без na 12946
# Строки с na 17054
# Доля в отношении к общему кол-ву строк (для na):  56.846666666666664 %

# %%
mask = reviews.isnull()
#print(mask)
print("Кол-во пропусков в столбце: \n", mask.sum())

print()

all_col = len(reviews.index)
print("Все строки", all_col)

not_na_col = len(reviews.dropna())
print("Строки без na", not_na_col)

na_col = all_col - not_na_col
print("Строки с na", na_col)

print("Доля в отношении к общему кол-ву строк (для na): " , na_col * 100 / all_col, "%")
# Out:
# Кол-во пропусков в столбце:
#  Unnamed: 0     0
# user_id        0
# recipe_id      0
# date           0
# rating         0
# review        17
# dtype: int64
#
# Все строки 126696
# Строки без na 126679
# Строки с na 17
# Доля в отношении к общему кол-ву строк (для na):  0.013417945317926375 %

# %% [markdown]
# 1.4 Рассчитайте среднее значение для каждого из числовых столбцов (где это имеет смысл).

# %%
recipes
# Out:
#                                                name      id  minutes  \
# 0             george s at the cove  black bean soup   44123       90
# 1                healthy for them  yogurt popsicles   67664       10
# 2                      i can t believe it s spinach   38798       30
# 3                              italian  gut busters   35173       45
# 4          love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29995  zurie s holey rustic olive and cheddar bread  267661       80
# 29996          zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   zwiebelkuchen   southwest german onion cake  103312       75
# 29998                                   zydeco soup  486161       60
# 29999        cookies by design   cookies on a stick  298512       29
#
#        contributor_id  submitted  n_steps  \
# 0               35193 2002-10-25      NaN
# 1               91970 2003-07-26      NaN
# ...

# %%
print("minutes: ", recipes["minutes"].mean(), "\nn_steps: ", recipes["n_steps"].mean(), "\nn_ingredients: ", recipes["n_ingredients"].mean())
# Out:
# minutes:  123.35813333333333
# n_steps:  9.805582137161085
# n_ingredients:  9.008285984848484

# %%
print("rating: ", reviews["rating"].mean())
# Out:
# rating:  4.410802235271832

# %% [markdown]
# 1.5 Создайте серию из 10 случайных названий рецептов.

# %%
recipes_10 = recipes['name'].sample(10) #Возвращает случайную выборку элементов с оси объекта.
print("Случайные 10 названий рецептов (ключ + значение)\n" ,recipes_10)

my_val = recipes_10.values
print("\nСлучайные 10 названий рецептов: ")
my_val
# Out:
# Случайные 10 названий рецептов (ключ + значение)
#  13537                          hearty potato and leek soup
# 13226                                 ham and corn chowder
# 22319                               red fruit soup  norway
# 24437                                     sloppy joes  sbd
# 18357                       mussels with tomato wine broth
# 11505    friendly neighbor bread  bread machine 1 pound...
# 3051                         billy s chocolate buttercream
# 20396                                       pecan truffles
# 8780     crumb crusted baked salmon with lemon caper sauce
# 15320                            kfc mac   cheese  copycat
# Name: name, dtype: object
#
# Случайные 10 названий рецептов:
# array(['hearty potato and leek soup', 'ham and corn chowder',
#        'red fruit soup  norway', 'sloppy joes  sbd',
#        'mussels with tomato wine broth',
#        'friendly neighbor bread  bread machine 1 pound loaf',
# ...

# %% [markdown]
# 1.6 Измените индекс в таблице `reviews`, пронумеровав строки, начиная с нуля.

# %%
reviews
# Out:
#         Unnamed: 0     user_id  recipe_id       date  rating  \
# 0           370476       21752      57993 2003-05-01       5
# 1           624300      431813     142201 2007-09-16       5
# 2           187037      400708     252013 2008-01-10       4
# 3           706134  2001852463     404716 2017-12-11       5
# 4           312179       95810     129396 2008-03-14       5
# ...            ...         ...        ...        ...     ...
# 126691     1013457     1270706     335534 2009-05-17       4
# 126692      158736     2282344       8701 2012-06-03       0
# 126693     1059834      689540     222001 2008-04-08       5
# 126694      453285  2000242659     354979 2015-06-02       5
# 126695      691207      463435     415599 2010-09-30       5
#
#                                                    review
# 0       Last week whole sides of frozen salmon fillet ...
# 1       So simple and so tasty!  I used a yellow capsi...
# ...

# %%
#new_reviews_index = reviews.reset_index(drop=True)
#new_reviews_index
reviews.rename(columns={"Unnamed: 0":"index"},inplace = True) # поменяли название столбца на index, inplace = новый массив
reviews
# Out:
#           index     user_id  recipe_id       date  rating  \
# 0        370476       21752      57993 2003-05-01       5
# 1        624300      431813     142201 2007-09-16       5
# 2        187037      400708     252013 2008-01-10       4
# 3        706134  2001852463     404716 2017-12-11       5
# 4        312179       95810     129396 2008-03-14       5
# ...         ...         ...        ...        ...     ...
# 126691  1013457     1270706     335534 2009-05-17       4
# 126692   158736     2282344       8701 2012-06-03       0
# 126693  1059834      689540     222001 2008-04-08       5
# 126694   453285  2000242659     354979 2015-06-02       5
# 126695   691207      463435     415599 2010-09-30       5
#
#                                                    review
# 0       Last week whole sides of frozen salmon fillet ...
# 1       So simple and so tasty!  I used a yellow capsi...
# 2       Very nice breakfast HH, easy to make and yummy...
# ...

# %%
reviews = reviews.set_index("index") #Индекс может заменить существующий индекс или расширить его (в нашем случае меняем индексы 0-126695 на столбец index с его данными(они станут новыми индексами) )
reviews
# Out:
#             user_id  recipe_id       date  rating  \
# index
# 370476        21752      57993 2003-05-01       5
# 624300       431813     142201 2007-09-16       5
# 187037       400708     252013 2008-01-10       4
# 706134   2001852463     404716 2017-12-11       5
# 312179        95810     129396 2008-03-14       5
# ...             ...        ...        ...     ...
# 1013457     1270706     335534 2009-05-17       4
# 158736      2282344       8701 2012-06-03       0
# 1059834      689540     222001 2008-04-08       5
# 453285   2000242659     354979 2015-06-02       5
# 691207       463435     415599 2010-09-30       5
#
#                                                     review
# index
# 370476   Last week whole sides of frozen salmon fillet ...
# 624300   So simple and so tasty!  I used a yellow capsi...
# 187037   Very nice breakfast HH, easy to make and yummy...
# 706134   These are a favorite for the holidays and so e...
# ...

# %%
recipes
# Out:
#                                                name      id  minutes  \
# 0             george s at the cove  black bean soup   44123       90
# 1                healthy for them  yogurt popsicles   67664       10
# 2                      i can t believe it s spinach   38798       30
# 3                              italian  gut busters   35173       45
# 4          love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29995  zurie s holey rustic olive and cheddar bread  267661       80
# 29996          zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   zwiebelkuchen   southwest german onion cake  103312       75
# 29998                                   zydeco soup  486161       60
# 29999        cookies by design   cookies on a stick  298512       29
#
#        contributor_id  submitted  n_steps  \
# 0               35193 2002-10-25      NaN
# 1               91970 2003-07-26      NaN
# ...

# %% [markdown]
# 1.7 Выведите информацию о рецептах, время выполнения которых не больше 20 минут и кол-во ингредиентов в которых не больше 5.

# %%
#print((recipes['minutes'] <= 20) & (recipes['n_ingredients'] <= 5))
recipes[(recipes['minutes'] <= 20) & (recipes['n_ingredients'] <= 5)] # печетаем всю строку
# Out:
# 26223    False
# 28083    False
# 26222    False
# 27876    False
# 5734     False
#          ...
# 3253     False
# 4138     False
# 2357     False
# 15052    False
# 4710     False
# Length: 30000, dtype: bool
#                                                     name      id  minutes  \
# 29193  When Dinner At 4 00Pm Turns Into Dinner At 6 00Pm  238287        5
# 12665    Green Beans From A Can That Don T Taste Like It  162873        5
# 3934   Brown Sugar And Rum Glazed Pineapple With Coco...  372902        5
# 12673  Green Beans Sauteed In Walnut Oil With Toasted...   40577       10
# 2792   Bella Notte   Coffee With Raspberry Di Amore A...  349920        2
# ...                                                  ...     ...      ...
# 5457                                           Chewbacca   59043        2
# 25722                                             Splice   29105        5
# 18174                                         Mousetraps  288829       10
# ...

# %% [markdown]
# ### Работа с датами в `pandas`

# %% [markdown]
# 2.1 Преобразуйте столбец `submitted` из таблицы `recipes` в формат времени. Модифицируйте решение задачи 1.1 так, чтобы считать столбец сразу в нужном формате.

# %%
recipes
# Out:
#                                                name      id  minutes  \
# 0             george s at the cove  black bean soup   44123       90
# 1                healthy for them  yogurt popsicles   67664       10
# 2                      i can t believe it s spinach   38798       30
# 3                              italian  gut busters   35173       45
# 4          love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29995  zurie s holey rustic olive and cheddar bread  267661       80
# 29996          zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   zwiebelkuchen   southwest german onion cake  103312       75
# 29998                                   zydeco soup  486161       60
# 29999        cookies by design   cookies on a stick  298512       29
#
#        contributor_id  submitted  n_steps  \
# 0               35193 2002-10-25      NaN
# 1               91970 2003-07-26      NaN
# ...

# %%
recipes.dtypes
# Out:
# name                      object
# id                         int64
# minutes                    int64
# contributor_id             int64
# submitted         datetime64[ns]
# n_steps                  float64
# description               object
# n_ingredients            float64
# dtype: object

# %%
recipes
# Out:
#                                                name      id  minutes  \
# 0             george s at the cove  black bean soup   44123       90
# 1                healthy for them  yogurt popsicles   67664       10
# 2                      i can t believe it s spinach   38798       30
# 3                              italian  gut busters   35173       45
# 4          love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29995  zurie s holey rustic olive and cheddar bread  267661       80
# 29996          zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   zwiebelkuchen   southwest german onion cake  103312       75
# 29998                                   zydeco soup  486161       60
# 29999        cookies by design   cookies on a stick  298512       29
#
#        contributor_id  submitted  n_steps  \
# 0               35193 2002-10-25      NaN
# 1               91970 2003-07-26      NaN
# ...

# %% [markdown]
# 2.2 Выведите информацию о рецептах, добавленных в датасет не позже 2010 года.

# %%
recipes[recipes["submitted"].dt.year < 2011]
# Out:
#                                                name      id  minutes  \
# 0             george s at the cove  black bean soup   44123       90
# 1                healthy for them  yogurt popsicles   67664       10
# 2                      i can t believe it s spinach   38798       30
# 3                              italian  gut busters   35173       45
# 4          love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29993                     zuni caf zucchini pickles  316950     2895
# 29995  zurie s holey rustic olive and cheddar bread  267661       80
# 29996          zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   zwiebelkuchen   southwest german onion cake  103312       75
# 29999        cookies by design   cookies on a stick  298512       29
#
#        contributor_id  submitted  n_steps  \
# 0               35193 2002-10-25      NaN
# 1               91970 2003-07-26      NaN
# ...

# %% [markdown]
# ### Работа со строковыми данными в `pandas`

# %% [markdown]
# 3.1  Добавьте в таблицу `recipes` столбец `description_length`, в котором хранится длина описания рецепта из столбца `description`.

# %%
recipes["description_length"] = recipes["description"].str.len()
recipes
# Out:
#                                                name      id  minutes  \
# 0             george s at the cove  black bean soup   44123       90
# 1                healthy for them  yogurt popsicles   67664       10
# 2                      i can t believe it s spinach   38798       30
# 3                              italian  gut busters   35173       45
# 4          love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29995  zurie s holey rustic olive and cheddar bread  267661       80
# 29996          zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   zwiebelkuchen   southwest german onion cake  103312       75
# 29998                                   zydeco soup  486161       60
# 29999        cookies by design   cookies on a stick  298512       29
#
#        contributor_id  submitted  n_steps  \
# 0               35193 2002-10-25      NaN
# 1               91970 2003-07-26      NaN
# ...

# %% [markdown]
# 3.2 Измените название каждого рецепта в таблице `recipes` таким образом, чтобы каждое слово в названии начиналось с прописной буквы.

# %%
recipes["name"] = recipes["name"].str.title()
recipes
# Out:
#                                                name      id  minutes  \
# 0             George S At The Cove  Black Bean Soup   44123       90
# 1                Healthy For Them  Yogurt Popsicles   67664       10
# 2                      I Can T Believe It S Spinach   38798       30
# 3                              Italian  Gut Busters   35173       45
# 4          Love Is In The Air  Beef Fondue   Sauces   84797       25
# ...                                             ...     ...      ...
# 29995  Zurie S Holey Rustic Olive And Cheddar Bread  267661       80
# 29996          Zwetschgenkuchen  Bavarian Plum Cake  386977      240
# 29997   Zwiebelkuchen   Southwest German Onion Cake  103312       75
# 29998                                   Zydeco Soup  486161       60
# 29999        Cookies By Design   Cookies On A Stick  298512       29
#
#        contributor_id  submitted  n_steps  \
# 0               35193 2002-10-25      NaN
# 1               91970 2003-07-26      NaN
# ...

# %% [markdown]
# 3.3 Добавьте в таблицу `recipes` столбец `name_word_count`, в котором хранится количество слов из названии рецепта (считайте, что слова в названии разделяются только пробелами).

# %%
recipes["name_word_count"] = recipes["name"].str.strip().str.split().str.len()
recipes
# Out:
#                                                name      id  minutes  \
# 0             George S At The Cove  Black Bean Soup   44123       90
# 1                Healthy For Them  Yogurt Popsicles   67664       10
# 2                      I Can T Believe It S Spinach   38798       30
# 3                              Italian  Gut Busters   35173       45
# 4          Love Is In The Air  Beef Fondue   Sauces   84797       25
# ...                                             ...     ...      ...
# 29995  Zurie S Holey Rustic Olive And Cheddar Bread  267661       80
# 29996          Zwetschgenkuchen  Bavarian Plum Cake  386977      240
# 29997   Zwiebelkuchen   Southwest German Onion Cake  103312       75
# 29998                                   Zydeco Soup  486161       60
# 29999        Cookies By Design   Cookies On A Stick  298512       29
#
#        contributor_id  submitted  n_steps  \
# 0               35193 2002-10-25      NaN
# 1               91970 2003-07-26      NaN
# ...

# %% [markdown]
# ### Группировки таблиц `pd.DataFrame`

# %% [markdown]
# 4.1 Посчитайте количество рецептов, представленных каждым из участников (`contributor_id`). Какой участник добавил максимальное кол-во рецептов?

# %%
recipes
# Out:
#                                                name      id  minutes  \
# 0             George S At The Cove  Black Bean Soup   44123       90
# 1                Healthy For Them  Yogurt Popsicles   67664       10
# 2                      I Can T Believe It S Spinach   38798       30
# 3                              Italian  Gut Busters   35173       45
# 4          Love Is In The Air  Beef Fondue   Sauces   84797       25
# ...                                             ...     ...      ...
# 29995  Zurie S Holey Rustic Olive And Cheddar Bread  267661       80
# 29996          Zwetschgenkuchen  Bavarian Plum Cake  386977      240
# 29997   Zwiebelkuchen   Southwest German Onion Cake  103312       75
# 29998                                   Zydeco Soup  486161       60
# 29999        Cookies By Design   Cookies On A Stick  298512       29
#
#        contributor_id  submitted  n_steps  \
# 0               35193 2002-10-25      NaN
# 1               91970 2003-07-26      NaN
# ...

# %%
num_recipes_user = recipes.groupby("contributor_id")["id"].count() #группируем по contribution_id, считаем кол-во повторяющихся/уникальных строк (ищем по айди в группированном массиве) 
print(num_recipes_user)

max_recipes_user = num_recipes_user.argmax()
max_recipes_user
# Out:
# contributor_id
# 1530            5
# 1533          186
# 1534           50
# 1535           40
# 1538            8
#              ...
# 2001968497      2
# 2002059754      1
# 2002234079      1
# 2002234259      1
# 2002247884      1
# Name: id, Length: 8404, dtype: int64
# 1768

# %% [markdown]
# 4.2 Посчитайте средний рейтинг к каждому из рецептов. Для скольких рецептов отсутствуют отзывы?

# %%
recipes
# Out:
#                                                name      id  minutes  \
# 0             George S At The Cove  Black Bean Soup   44123       90
# 1                Healthy For Them  Yogurt Popsicles   67664       10
# 2                      I Can T Believe It S Spinach   38798       30
# 3                              Italian  Gut Busters   35173       45
# 4          Love Is In The Air  Beef Fondue   Sauces   84797       25
# ...                                             ...     ...      ...
# 29995  Zurie S Holey Rustic Olive And Cheddar Bread  267661       80
# 29996          Zwetschgenkuchen  Bavarian Plum Cake  386977      240
# 29997   Zwiebelkuchen   Southwest German Onion Cake  103312       75
# 29998                                   Zydeco Soup  486161       60
# 29999        Cookies By Design   Cookies On A Stick  298512       29
#
#        contributor_id  submitted  n_steps  \
# 0               35193 2002-10-25      NaN
# 1               91970 2003-07-26      NaN
# ...

# %%
reviews
# Out:
#             user_id  recipe_id       date  rating  \
# index
# 370476        21752      57993 2003-05-01       5
# 624300       431813     142201 2007-09-16       5
# 187037       400708     252013 2008-01-10       4
# 706134   2001852463     404716 2017-12-11       5
# 312179        95810     129396 2008-03-14       5
# ...             ...        ...        ...     ...
# 1013457     1270706     335534 2009-05-17       4
# 158736      2282344       8701 2012-06-03       0
# 1059834      689540     222001 2008-04-08       5
# 453285   2000242659     354979 2015-06-02       5
# 691207       463435     415599 2010-09-30       5
#
#                                                     review
# index
# 370476   Last week whole sides of frozen salmon fillet ...
# 624300   So simple and so tasty!  I used a yellow capsi...
# 187037   Very nice breakfast HH, easy to make and yummy...
# 706134   These are a favorite for the holidays and so e...
# ...

# %%
recipes_and_reviews = recipes.merge(reviews, how="left", left_on="id", right_on="recipe_id")
recipes_and_reviews
# Out:
#                                           name      id  minutes  \
# 0        George S At The Cove  Black Bean Soup   44123       90
# 1        George S At The Cove  Black Bean Soup   44123       90
# 2        George S At The Cove  Black Bean Soup   44123       90
# 3           Healthy For Them  Yogurt Popsicles   67664       10
# 4           Healthy For Them  Yogurt Popsicles   67664       10
# ...                                        ...     ...      ...
# 128591                             Zydeco Soup  486161       60
# 128592                             Zydeco Soup  486161       60
# 128593                             Zydeco Soup  486161       60
# 128594                             Zydeco Soup  486161       60
# 128595  Cookies By Design   Cookies On A Stick  298512       29
#
#         contributor_id  submitted  n_steps  \
# 0                35193 2002-10-25      NaN
# 1                35193 2002-10-25      NaN
# 2                35193 2002-10-25      NaN
# ...

# %%
groupby_recipe = recipes_and_reviews.groupby('id') #по id группировка
#print(recipes_and_reviews[(recipes_and_reviews["id"] == 48)])

mean_recipe_ratings = groupby_recipe["rating"].mean()
print(mean_recipe_ratings)
print("------------------------------------------------")
print(groupby_recipe["review"].size())
print("--------------------------------------------------")
print(groupby_recipe["review"].count())
recipes_without_review = (groupby_recipe["review"].size() - groupby_recipe["review"].count()) #из всех вычитаем не пустые = кол-во пустых
recipes_without_review.sum() # сложим и получим пустые отзывы
#all_recipe_ratings = recipes
# Out:
#                    name  id  minutes  contributor_id  submitted  n_steps  \
# 16578  Boston Cream Pie  48      135            1545 1999-08-24     32.0
# 16579  Boston Cream Pie  48      135            1545 1999-08-24     32.0
#
#       description  n_ingredients  description_length  name_word_count  \
# 16578         NaN           15.0                 NaN                3
# 16579         NaN           15.0                 NaN                3
#
#        user_id  recipe_id       date  rating  \
# 16578  32421.0       48.0 2002-03-15     0.0
# 16579  68674.0       48.0 2004-05-03     2.0
#
#                                                   review
# 16578  The flavor was great. But I think there was no...
# 16579  I picked this recipe over the other BCP recipe...
# id
# 48        1.000000
# 55        4.750000
# 66        4.944444
# 91        4.750000
# 94        5.000000
#             ...
# 536547    5.000000
# 536610    0.000000
# 536728    4.000000
# 536729    4.750000
# ...

# %% [markdown]
# 4.3 Посчитайте количество рецептов с разбивкой по годам создания.

# %%
recipes
# Out:
#                                                name      id  minutes  \
# 0             George S At The Cove  Black Bean Soup   44123       90
# 1                Healthy For Them  Yogurt Popsicles   67664       10
# 2                      I Can T Believe It S Spinach   38798       30
# 3                              Italian  Gut Busters   35173       45
# 4          Love Is In The Air  Beef Fondue   Sauces   84797       25
# ...                                             ...     ...      ...
# 29995  Zurie S Holey Rustic Olive And Cheddar Bread  267661       80
# 29996          Zwetschgenkuchen  Bavarian Plum Cake  386977      240
# 29997   Zwiebelkuchen   Southwest German Onion Cake  103312       75
# 29998                                   Zydeco Soup  486161       60
# 29999        Cookies By Design   Cookies On A Stick  298512       29
#
#        contributor_id  submitted  n_steps  \
# 0               35193 2002-10-25      NaN
# 1               91970 2003-07-26      NaN
# ...

# %%
num_year = recipes.groupby(recipes["submitted"].dt.year)["id"].count() # группируем по submitted и считаем кол-во id
num_year
# Out:
# submitted
# 1999     275
# 2000     104
# 2001     589
# 2002    2644
# 2003    2334
# 2004    2153
# 2005    3130
# 2006    3473
# 2007    4429
# 2008    4029
# 2009    2963
# 2010    1538
# 2011     922
# 2012     659
# 2013     490
# 2014     139
# 2015      42
# 2016      24
# 2017      39
# 2018      24
# Name: id, dtype: int64

# %% [markdown]
# ### Объединение таблиц `pd.DataFrame`

# %% [markdown]
# 5.1 При помощи объединения таблиц, создайте `DataFrame`, состоящий из четырех столбцов: `id`, `name`, `user_id`, `rating`. Рецепты без отзывов должны отсутствовать в данной таблице. Подтвердите правильность работы вашего кода, выбрав рецепт, не имеющий отзывов, и выведя на экран строку из полученного `DataFrame`, содержащую информацию об этом отзыве.

# %%
recipes
# Out:
#                                                name      id  minutes  \
# 0             George S At The Cove  Black Bean Soup   44123       90
# 1                Healthy For Them  Yogurt Popsicles   67664       10
# 2                      I Can T Believe It S Spinach   38798       30
# 3                              Italian  Gut Busters   35173       45
# 4          Love Is In The Air  Beef Fondue   Sauces   84797       25
# ...                                             ...     ...      ...
# 29995  Zurie S Holey Rustic Olive And Cheddar Bread  267661       80
# 29996          Zwetschgenkuchen  Bavarian Plum Cake  386977      240
# 29997   Zwiebelkuchen   Southwest German Onion Cake  103312       75
# 29998                                   Zydeco Soup  486161       60
# 29999        Cookies By Design   Cookies On A Stick  298512       29
#
#        contributor_id  submitted  n_steps  \
# 0               35193 2002-10-25      NaN
# 1               91970 2003-07-26      NaN
# ...

# %%
reviews
# Out:
#             user_id  recipe_id       date  rating  \
# index
# 370476        21752      57993 2003-05-01       5
# 624300       431813     142201 2007-09-16       5
# 187037       400708     252013 2008-01-10       4
# 706134   2001852463     404716 2017-12-11       5
# 312179        95810     129396 2008-03-14       5
# ...             ...        ...        ...     ...
# 1013457     1270706     335534 2009-05-17       4
# 158736      2282344       8701 2012-06-03       0
# 1059834      689540     222001 2008-04-08       5
# 453285   2000242659     354979 2015-06-02       5
# 691207       463435     415599 2010-09-30       5
#
#                                                     review
# index
# 370476   Last week whole sides of frozen salmon fillet ...
# 624300   So simple and so tasty!  I used a yellow capsi...
# 187037   Very nice breakfast HH, easy to make and yummy...
# 706134   These are a favorite for the holidays and so e...
# ...

# %%
new_table = pd.merge(
    recipes,
    reviews,
    how='inner',
    left_on='id',
    right_on='recipe_id'
)[['id', 'name', 'user_id', 'rating']]
new_table
# Out:
#             id                                    name  user_id  rating
# 0        44123   George S At The Cove  Black Bean Soup   743566       5
# 1        44123   George S At The Cove  Black Bean Soup    76503       5
# 2        44123   George S At The Cove  Black Bean Soup    34206       5
# 3        67664      Healthy For Them  Yogurt Popsicles   494084       5
# 4        67664      Healthy For Them  Yogurt Popsicles   303445       5
# ...        ...                                     ...      ...     ...
# 126691  486161                             Zydeco Soup   305531       5
# 126692  486161                             Zydeco Soup  1271506       5
# 126693  486161                             Zydeco Soup   724631       5
# 126694  486161                             Zydeco Soup   133174       5
# 126695  298512  Cookies By Design   Cookies On A Stick   804234       1
#
# [126696 rows x 4 columns]

# %%
unic_recipes = set(recipes["id"]) 
unic_review = set(reviews["recipe_id"])
rec_without_rev = pd.Series(list(unic_recipes - unic_reviews)) # получим айди тех recipe, на которых не оставили отзыва
print(rec_without_rev)
test_recipe = rec_without_rev.sample(1) # возвратит 1 строку (индекс и сам айди)
print("------------------------------------------------------------------------")
print(test_recipe)
sample_recipe = test_recipe.values[0]
#так как нету id recipe у тех кто в review не оставил отзыва на recipe, а мы создали таблицу, состояшую только из тех, кто написал отзыв, то докажем, пройдя по всем значениям id из таблицы new recipes и сравнивая с рандомным id user который не оставил отзыв -> тем самым, такой строки в таблице не найдется, ибо в таблице только те кто написал отзыв
new_table[new_table["id"] == sample_recipe]
# Out:
# 0       401411
# 1       442372
# 2       270343
# 3        16395
# 4       294929
#          ...
# 1895    294898
# 1896    278516
# 1897    278519
# 1898     32760
# 1899    188409
# Length: 1900, dtype: int64
# ------------------------------------------------------------------------
# 1108    103059
# dtype: int64
# Empty DataFrame
# Columns: [id, name, user_id, rating]
# Index: []

# %% [markdown]
# 5.2 При помощи объединения таблиц и группировок, создайте `DataFrame`, состоящий из трех столбцов: `recipe_id`, `name`, `review_count`. У рецептов, для которых отсутствуют отзывы, в соответствущем столбце должен быть указан 0. Подтвердите правильность работы вашего кода, выбрав рецепт, не имеющий отзывов, и выведя на экран строку из полученного `DataFrame`, содержащую информацию об этом отзыве.

# %%
reviews
# Out:
#             user_id  recipe_id       date  rating  \
# index
# 370476        21752      57993 2003-05-01       5
# 624300       431813     142201 2007-09-16       5
# 187037       400708     252013 2008-01-10       4
# 706134   2001852463     404716 2017-12-11       5
# 312179        95810     129396 2008-03-14       5
# ...             ...        ...        ...     ...
# 1013457     1270706     335534 2009-05-17       4
# 158736      2282344       8701 2012-06-03       0
# 1059834      689540     222001 2008-04-08       5
# 453285   2000242659     354979 2015-06-02       5
# 691207       463435     415599 2010-09-30       5
#
#                                                     review
# index
# 370476   Last week whole sides of frozen salmon fillet ...
# 624300   So simple and so tasty!  I used a yellow capsi...
# 187037   Very nice breakfast HH, easy to make and yummy...
# 706134   These are a favorite for the holidays and so e...
# ...

# %%
recipes
# Out:
#                                                     name      id  minutes  \
# 26223  Subru Uncle S Whole Green Moong Dal I Ll Be Ma...   77188       95
# 28083  Tsr Version Of T G I  Friday S Black Bean Soup...  102274       75
# 26222  Subru Uncle S Toor Ki Dal Sindhi Style  Dad  M...   76908       65
# 27876  Top Secret Recipes Version Of  I H O P  Griddl...  113346       20
# 5734   Chicken Curry Or  Cat S Vomit On A Bed Of Magg...  294898       30
# ...                                                  ...     ...      ...
# 3253                                          Blackmoons  323195      430
# 4138                                         Bushwhacker  156521       10
# 2357                                            Basbousa   12957       60
# 15052                                          Josefinas  264859       20
# 4710                                            Caramels  143615       30
#
#        contributor_id  submitted  n_steps  \
# ...

# %%
#ff = reviews.groupby('recipe_id')['review'].count()
#ff

# %%
grouped_df = reviews.groupby('recipe_id')['review'].count().reset_index()
print(grouped_df)
new_table2 = pd.merge(
    recipes,
    grouped_df.rename(columns={'review': 'review_count'}),
    how='inner',
    left_on='id',
    right_on='recipe_id'
)[['recipe_id', 'name', "review_count"]]
new_table2
# Out:
#        recipe_id  review
# 0             48       2
# 1             55       4
# 2             66      18
# 3             91       4
# 4             94       4
# ...          ...     ...
# 28095     536547       1
# 28096     536610       1
# 28097     536728       1
# 28098     536729       4
# 28099     536747       4
#
# [28100 rows x 2 columns]
#        recipe_id                                               name  \
# 0          77188  Subru Uncle S Whole Green Moong Dal I Ll Be Ma...
# 1         102274  Tsr Version Of T G I  Friday S Black Bean Soup...
# 2          76908  Subru Uncle S Toor Ki Dal Sindhi Style  Dad  M...
# 3         113346  Top Secret Recipes Version Of  I H O P  Griddl...
# 4         414683  Mama D S Mama D S Busy Night  Not Quite Chicke...
# ...          ...                                                ...
# 28095     323195                                         Blackmoons
# 28096     156521                                        Bushwhacker
# ...

# %%
recipes_reviews_df = new_table2.fillna(0) # на место na 0
recipes_reviews_df

unic_recipes = set(recipes["id"])  # все айди рецептов
unic_review = set(reviews["recipe_id"]) #все айди рецетов в отзывах

rec_without_rev = pd.Series(list(unic_recipes - unic_review))
#print(rec_without_rev)

test_recipe = rec_without_rev.sample(1)
print(test_recipe)
sample_recipe = test_recipe.values[0]
print(sample_recipe)
new_table2[new_table2["recipe_id"] == sample_recipe]
# Out:
# 1574    39574
# dtype: int64
# 39574
# Empty DataFrame
# Columns: [recipe_id, name, review_count]
# Index: []

# %% [markdown]
# 5.3. Выясните, отзывы, добавленные в каком году, имеют наименьший средний рейтинг?

# %%
reviews
# Out:
#             user_id  recipe_id       date  rating  \
# index
# 370476        21752      57993 2003-05-01       5
# 624300       431813     142201 2007-09-16       5
# 187037       400708     252013 2008-01-10       4
# 706134   2001852463     404716 2017-12-11       5
# 312179        95810     129396 2008-03-14       5
# ...             ...        ...        ...     ...
# 1013457     1270706     335534 2009-05-17       4
# 158736      2282344       8701 2012-06-03       0
# 1059834      689540     222001 2008-04-08       5
# 453285   2000242659     354979 2015-06-02       5
# 691207       463435     415599 2010-09-30       5
#
#                                                     review
# index
# 370476   Last week whole sides of frozen salmon fillet ...
# 624300   So simple and so tasty!  I used a yellow capsi...
# 187037   Very nice breakfast HH, easy to make and yummy...
# 706134   These are a favorite for the holidays and so e...
# ...

# %%
rating_by_year = reviews.groupby(reviews["date"].dt.year)['rating']
print("общее кол-во повторений\n",rating_by_year.count()) # год на кол-во повторений рейтинга
rating_by_year_mean = rating_by_year.mean() # сложит все рейтинги/общее кол-во
print("среднее\n", rating_by_year_mean)
#rating_by_year_mean.describe()
rating_by_year_mean.idxmin() # получаем индекс самого маленького значения (По ср знач)
# Out:
# общее кол-во повторений
#  date
# 2000       13
# 2001      305
# 2002     2494
# 2003     3879
# 2004     5070
# 2005     7577
# 2006     9964
# 2007    15634
# 2008    18614
# 2009    17672
# 2010    12094
# 2011     8118
# 2012     6095
# 2013     5679
# 2014     3445
# 2015     2715
# 2016     2071
# 2017     2926
# 2018     2331
# Name: rating, dtype: int64
# среднее
#  date
# 2000    3.384615
# 2001    4.134426
# 2002    4.481556
# 2003    4.526940
# 2004    4.546548
# 2005    4.563680
# 2006    4.603673
# 2007    4.547077
# 2008    4.484635
# 2009    4.524728
# 2010    4.454440
# 2011    4.302045
# 2012    4.341427
# 2013    4.274168
# 2014    4.110595
# 2015    4.047145
# 2016    3.912603
# 2017    3.353042
# 2018    3.504076
# Name: rating, dtype: float64
# 2017

# %% [markdown]
# ### Сохранение таблиц `pd.DataFrame`

# %% [markdown]
# 6.1 Отсортируйте таблицу в порядке убывания величины столбца `name_word_count` и сохраните результаты выполнения заданий 3.1-3.3 в csv файл.

# %%
recipes
# Out:
#                                                name      id  minutes  \
# 0             George S At The Cove  Black Bean Soup   44123       90
# 1                Healthy For Them  Yogurt Popsicles   67664       10
# 2                      I Can T Believe It S Spinach   38798       30
# 3                              Italian  Gut Busters   35173       45
# 4          Love Is In The Air  Beef Fondue   Sauces   84797       25
# ...                                             ...     ...      ...
# 29995  Zurie S Holey Rustic Olive And Cheddar Bread  267661       80
# 29996          Zwetschgenkuchen  Bavarian Plum Cake  386977      240
# 29997   Zwiebelkuchen   Southwest German Onion Cake  103312       75
# 29998                                   Zydeco Soup  486161       60
# 29999        Cookies By Design   Cookies On A Stick  298512       29
#
#        contributor_id  submitted  n_steps  \
# 0               35193 2002-10-25      NaN
# 1               91970 2003-07-26      NaN
# ...

# %%
recipes = recipes.sort_values(by = "name_word_count", ascending=False) #desk - по убыванию
recipes
# Out:
#                                                     name      id  minutes  \
# 26223  Subru Uncle S Whole Green Moong Dal I Ll Be Ma...   77188       95
# 28083  Tsr Version Of T G I  Friday S Black Bean Soup...  102274       75
# 26222  Subru Uncle S Toor Ki Dal Sindhi Style  Dad  M...   76908       65
# 27876  Top Secret Recipes Version Of  I H O P  Griddl...  113346       20
# 5734   Chicken Curry Or  Cat S Vomit On A Bed Of Magg...  294898       30
# ...                                                  ...     ...      ...
# 3253                                          Blackmoons  323195      430
# 4138                                         Bushwhacker  156521       10
# 2357                                            Basbousa   12957       60
# 15052                                          Josefinas  264859       20
# 4710                                            Caramels  143615       30
#
#        contributor_id  submitted  n_steps  \
# ...

# %%
recipes.to_csv('./for_save/Kuznetsov_file_6_1.csv', index = False)
recipes.to_csv('./for_save/Kuznetsov_file_6_1_test.csv')

# %% [markdown]
# 6.2 Воспользовавшись `pd.ExcelWriter`, cохраните результаты 5.1 и 5.2 в файл: на лист с названием `Рецепты с оценками` сохраните результаты выполнения 5.1; на лист с названием `Количество отзывов по рецептам` сохраните результаты выполнения 5.2.

# %%
with pd.ExcelWriter("./for_save/itog3.xlsx") as excelWriter:
    new_table.to_excel(excelWriter, sheet_name="Рецепты с оценками", index = False)

    new_table.to_excel(excelWriter, sheet_name= "Количество отзывов по рецептам", index = False)
