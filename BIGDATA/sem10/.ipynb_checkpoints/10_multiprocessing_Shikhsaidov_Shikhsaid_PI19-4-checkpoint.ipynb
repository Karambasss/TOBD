# %% [markdown]
# # Параллельные вычисления

# %% [markdown]
# Материалы:
# * Макрушин С.В. Лекция 10: Параллельные вычисления
# * https://docs.python.org/3/library/multiprocessing.html

# %% [markdown]
# ## Задачи для совместного разбора

# %% [markdown]
# 1. Посчитайте, сколько раз встречается каждый из символов (заглавные и строчные символы не различаются) в файле `Dostoevskiy Fedor. Prestuplenie i nakazanie - BooksCafe.Net.txt` и в файле `Dostoevskiy Fedor. Igrok - BooksCafe.Net.txt`.

# %%
import multiprocessing as mp
import csv
import pandas as pd

# %%
# %%file let_count.py
from collections import Counter

def let_count(file):
    
    with open(file) as fp:
        text = fp.read().lower()
        return Counter(text)
# Out:
# Overwriting let_count.py

# %%
let_count("./data/Dostoevskiy Fedor. Prestuplenie i nakazanie - BooksCafe.Net.txt")
# Out:
# Counter({'с': 50084,
#          'п': 25652,
#          'а': 73555,
#          'и': 62030,
#          'б': 16016,
#          'о': 106740,
#          ',': 26973,
#          ' ': 182305,
#          'ч': 16492,
#          'т': 59813,
#          'к': 30802,
#          'л': 42328,
#          'н': 60920,
#          'г': 16174,
#          'у': 27309,
#          'в': 43700,
#          'е': 80972,
#          'й': 9747,
#          'э': 3203,
#          'р': 39784,
#          'b': 25,
#          'o': 104,
#          'k': 16,
#          's': 96,
#          'c': 42,
#          'a': 98,
#          'f': 23,
#          'e': 162,
#          '.': 9864,
#          'n': 114,
#          't': 98,
#          ':': 984,
#          'h': 48,
#          'p': 29,
#          '/': 22,
#          '\n': 8583,
#          'u': 86,
#          'r': 76,
#          'd': 38,
#          'v': 65,
#          'i': 235,
#          'y': 5,
#          '_': 8,
#          '-': 3558,
#          '1': 384,
#          '0': 110,
#          '9': 100,
#          '6': 271,
#          'm': 54,
#          'l': 46,
#          'ж': 10552,
#          'д': 29633,
#          'х': 8127,
#          'ф': 1237,
#          'м': 29312,
#          'z': 11,
#          '2': 141,
#          '8': 297,
#          '5': 136,
#          'я': 19751,
#          '!': 3280,
#          '\xa0': 6092,
#          'з': 14414,
#          'ш': 7437,
#          'ь': 20554,
#          'ю': 5418,
#          'ц': 2782,
#          '«': 1187,
#          '»': 1175,
#          'ы': 15449,
#          'щ': 3039,
#          'x': 52,
#          '—': 6440,
#          '(': 528,
#          ')': 527,
#          '[': 85,
#          ']': 85,
#          'ъ': 223,
#          '7': 121,
#          '3': 120,
#          '&': 22,
#          '#': 22,
#          ';': 1322,
#          '…': 2263,
#          '?': 2266,
#          '4': 130,
#          '–': 49,
#          '№': 45,
#          'ё': 969,
#          '\t': 48,
#          '„': 44,
#          '“': 44,
#          "'": 11,
#          'g': 19,
#          'j': 1,
#          'q': 9,
#          'w': 4})

# %%
let_count("./data/Dostoevskiy Fedor. Igrok - BooksCafe.Net.txt")
# Out:
# Counter({'с': 11507,
#          'п': 5489,
#          'а': 18236,
#          'и': 13587,
#          'б': 3980,
#          'о': 23130,
#          ',': 6372,
#          ' ': 45076,
#          'ч': 4113,
#          'т': 14245,
#          'к': 6744,
#          'л': 9961,
#          'н': 14240,
#          'г': 3948,
#          'у': 6044,
#          'в': 9398,
#          'е': 20054,
#          'й': 2028,
#          'э': 836,
#          'р': 9482,
#          'b': 220,
#          'o': 377,
#          'k': 21,
#          's': 429,
#          'c': 324,
#          'a': 590,
#          'f': 52,
#          'e': 1200,
#          '.': 2954,
#          'n': 459,
#          't': 332,
#          ':': 212,
#          'h': 227,
#          'p': 100,
#          '/': 20,
#          '\n': 2734,
#          'u': 285,
#          'r': 308,
#          'd': 192,
#          'v': 87,
#          'i': 369,
#          'y': 8,
#          '_': 4,
#          '-': 900,
#          '1': 46,
#          '0': 22,
#          '9': 36,
#          '6': 42,
#          'm': 401,
#          'l': 571,
#          'ж': 2297,
#          'д': 6681,
#          'х': 1535,
#          'ф': 634,
#          'м': 7106,
#          'g': 73,
#          '2': 42,
#          '4': 42,
#          '7': 42,
#          'я': 5458,
#          '!': 718,
#          '(': 276,
#          'з': 3355,
#          ')': 276,
#          'ц': 817,
#          'ь': 4857,
#          'ш': 1943,
#          'ы': 3869,
#          'ю': 1323,
#          ';': 406,
#          'щ': 587,
#          '?': 571,
#          'ъ': 63,
#          '—': 1726,
#          '\xa0': 1472,
#          '…': 280,
#          '«': 129,
#          '[': 97,
#          ']': 97,
#          '»': 128,
#          "'": 59,
#          '3': 40,
#          '5': 40,
#          'q': 50,
#          'j': 40,
#          '8': 38,
#          'w': 7,
#          'x': 24,
#          'z': 44,
#          '`': 9})

# %% [markdown]
# 2. Решить задачу 1, распараллелив вычисления с помощью модуля `multiprocessing`. Для обработки каждого файла создать свой собственный процесс.

# %%
from let_count import let_count

# %%
if __name__ == "__main__":
    files = ["./data/Dostoevskiy Fedor. Prestuplenie i nakazanie - BooksCafe.Net.txt", "./data/Dostoevskiy Fedor. Igrok - BooksCafe.Net.txt"]
    pool = mp.Pool(processes=4)
    counters = pool.map(let_count, files)

# %%
counters
# Out:
# [Counter({'с': 50084,
#           'п': 25652,
#           'а': 73555,
#           'и': 62030,
#           'б': 16016,
#           'о': 106740,
#           ',': 26973,
#           ' ': 182305,
#           'ч': 16492,
#           'т': 59813,
#           'к': 30802,
#           'л': 42328,
#           'н': 60920,
#           'г': 16174,
#           'у': 27309,
#           'в': 43700,
#           'е': 80972,
#           'й': 9747,
#           'э': 3203,
#           'р': 39784,
#           'b': 25,
#           'o': 104,
#           'k': 16,
#           's': 96,
#           'c': 42,
#           'a': 98,
#           'f': 23,
#           'e': 162,
#           '.': 9864,
#           'n': 114,
#           't': 98,
#           ':': 984,
#           'h': 48,
#           'p': 29,
#           '/': 22,
#           '\n': 8583,
#           'u': 86,
#           'r': 76,
#           'd': 38,
#           'v': 65,
#           'i': 235,
#           'y': 5,
#           '_': 8,
#           '-': 3558,
#           '1': 384,
#           '0': 110,
#           '9': 100,
#           '6': 271,
#           'm': 54,
#           'l': 46,
#           'ж': 10552,
#           'д': 29633,
#           'х': 8127,
#           'ф': 1237,
#           'м': 29312,
#           'z': 11,
#           '2': 141,
#           '8': 297,
#           '5': 136,
#           'я': 19751,
#           '!': 3280,
#           '\xa0': 6092,
#           'з': 14414,
#           'ш': 7437,
#           'ь': 20554,
#           'ю': 5418,
#           'ц': 2782,
#           '«': 1187,
#           '»': 1175,
#           'ы': 15449,
#           'щ': 3039,
#           'x': 52,
#           '—': 6440,
#           '(': 528,
#           ')': 527,
#           '[': 85,
#           ']': 85,
#           'ъ': 223,
#           '7': 121,
#           '3': 120,
#           '&': 22,
#           '#': 22,
#           ';': 1322,
#           '…': 2263,
#           '?': 2266,
#           '4': 130,
#           '–': 49,
#           '№': 45,
#           'ё': 969,
#           '\t': 48,
#           '„': 44,
#           '“': 44,
#           "'": 11,
#           'g': 19,
#           'j': 1,
#           'q': 9,
#           'w': 4}),
#  Counter({'с': 11507,
#           'п': 5489,
#           'а': 18236,
#           'и': 13587,
#           'б': 3980,
#           'о': 23130,
#           ',': 6372,
#           ' ': 45076,
#           'ч': 4113,
#           'т': 14245,
#           'к': 6744,
#           'л': 9961,
#           'н': 14240,
#           'г': 3948,
#           'у': 6044,
#           'в': 9398,
#           'е': 20054,
#           'й': 2028,
#           'э': 836,
#           'р': 9482,
#           'b': 220,
#           'o': 377,
#           'k': 21,
#           's': 429,
#           'c': 324,
#           'a': 590,
#           'f': 52,
#           'e': 1200,
#           '.': 2954,
#           'n': 459,
#           't': 332,
#           ':': 212,
#           'h': 227,
#           'p': 100,
#           '/': 20,
#           '\n': 2734,
#           'u': 285,
#           'r': 308,
#           'd': 192,
#           'v': 87,
#           'i': 369,
#           'y': 8,
#           '_': 4,
#           '-': 900,
#           '1': 46,
#           '0': 22,
#           '9': 36,
#           '6': 42,
#           'm': 401,
#           'l': 571,
#           'ж': 2297,
#           'д': 6681,
#           'х': 1535,
#           'ф': 634,
#           'м': 7106,
#           'g': 73,
#           '2': 42,
#           '4': 42,
#           '7': 42,
#           'я': 5458,
#           '!': 718,
#           '(': 276,
#           'з': 3355,
#           ')': 276,
#           'ц': 817,
#           'ь': 4857,
#           'ш': 1943,
#           'ы': 3869,
#           'ю': 1323,
#           ';': 406,
#           'щ': 587,
#           '?': 571,
#           'ъ': 63,
#           '—': 1726,
#           '\xa0': 1472,
#           '…': 280,
#           '«': 129,
#           '[': 97,
#           ']': 97,
#           '»': 128,
#           "'": 59,
#           '3': 40,
#           '5': 40,
#           'q': 50,
#           'j': 40,
#           '8': 38,
#           'w': 7,
#           'x': 24,
#           'z': 44,
#           '`': 9})]

# %% [markdown]
# ## Лабораторная работа 10

# %% [markdown]
# 1. Разбейте файл `recipes_full.csv` на несколько (например, 8) примерно одинаковых по объему файлов c названиями `id_tag_nsteps_*.csv`. Каждый файл содержит 3 столбца: `id`, `tag` и `n_steps`, разделенных символом `;`. Для разбора строк используйте `csv.reader`.
#
# __Важно__: вы не можете загружать в память весь файл сразу. Посмотреть на первые несколько строк файла вы можете, написав код, который считывает эти строки.
#
# Подсказка: примерное кол-во строк в файле - 2.3 млн.
#
# Фрагмент одного из файлов, которые должны получиться в результате:
# ```
# id;tag;n_steps
# 137739;60-minutes-or-less;11
# 137739;time-to-make;11
# 137739;course;11
# ```

# %%
with open('./data/recipes_full.csv', newline='', encoding="utf-8") as file:
    recipes = csv.DictReader(file)

    count = 0
    file_number = 1
    file_write = open('./output/id_tag_nsteps_' + str(file_number) + '.csv', 'w', encoding="utf-8")
    writer = csv.writer(file_write,  delimiter = ";", lineterminator="\r")   
    for row in recipes:
        count += 1
        if count < 287360:
            if count == 1:
                writer.writerow(["id", "tags", "n_steps"])
            lst = row["tags"][1:-1].split(", ")
            tag_lst = [i[1:-1] for i in lst]
            for tag in tag_lst:
                writer.writerow([row["id"], tag, row["n_steps"]])
        else:
            count = 0
            file_number += 1
            file_write.close()
            file_write = open('./output/id_tag_nsteps_' + str(file_number) + '.csv', 'w', encoding="utf-8")
            writer = csv.writer(file_write,  delimiter = ";", lineterminator="\r")

# %% [markdown]
# 2. Напишите функцию, которая принимает на вход название файла, созданного в результате решения задачи 1, считает среднее значение количества шагов для каждого тэга и возвращает результат в виде словаря.

# %%
# %%file mean_step_file.py
import pandas as pd

def mean_step(file):
    tags_dict = {}
    df = pd.read_csv(file, sep=";")
    df_tags = df.groupby('tags').mean()["n_steps"]
    df = df.dropna()
    df_tags = df_tags.dropna()
    for tag in df["tags"]:
        if tag not in tags_dict:
            tags_dict[tag] = df_tags[tag]
    return tags_dict
# Out:
# Writing mean_step_file.py

# %%
tags_dict = mean_step('./output/id_tag_nsteps_1.csv')
tags_dict
# Out:
# {'mexican': 5.310914454277286,
#  'healthy-2': 6.334017094017094,
#  'orange-roughy': 3.4486692015209126,
#  'chicken-thighs-legs': 4.181159420289855,
#  'freezer': 3.9193485847227607,
#  'whitefish': 3.525452250736222,
#  'pork-sausage': 4.298745724059293,
#  'brunch': 6.907961246840775,
#  'ham-and-bean-soup': 3.5179180887372015,
#  'colombian': 3.5746367239101717,
#  'savory-pies': 4.292712066905615,
#  'refrigerator': 4.749388325760224,
#  'australian': 4.247299813780261,
#  'served-cold': 4.941708229426434,
#  'spaghetti': 4.130796670630202,
#  'passover': 3.629370629370629,
#  'quick-breads': 4.964539007092198,
#  'californian': 3.7518218623481783,
#  'namibian': 3.5014861995753717,
#  'candy': 4.293940534437335,
#  'independence-day': 4.14301717699776,
#  'baking': 3.5878839590443685,
#  'pennsylvania-dutch': 3.538971807628524,
#  'weeknight': 7.436413361984763,
#  '60-minutes-or-less': 9.321623731459797,
#  'time-to-make': 9.247789003241746,
#  'course': 9.237364209978534,
#  'cuisine': 9.127411772960079,
#  'preparation': 9.28979490674763,
#  'occasion': 9.164456850430332,
#  'north-american': 8.154118587912716,
#  'desserts': 9.147767630644344,
#  'dinner-party': 8.246384720327422,
#  'holiday-event': 8.331905465288035,
#  'cookies-and-brownies': 6.801326192297883,
#  'gelatin': 3.7768662838392126,
#  'high-in-something': 5.4887799845241165,
#  'barbecue': 4.632081911262799,
#  'main-ingredient': 9.318265418727265,
#  'main-dish': 9.422488988686416,
#  'poultry': 7.632594195060393,
#  'easy': 7.239655813459393,
#  'chicken': 7.331425187524674,
#  'one-dish-meal': 6.928635346756153,
#  'comfort-food': 7.494499738082766,
#  'meat': 8.937246753246754,
#  'chicken-breasts': 5.82372175980975,
#  'taste-mood': 8.537395512538495,
#  'peppers': 4.498738738738739,
#  'grapes': 3.567295597484277,
#  'veal': 3.6587030716723548,
#  'kid-friendly': 7.0738095238095235,
#  'breakfast-casseroles': 3.494188549289712,
#  'peruvian': 3.604651162790698,
#  'filipino': 3.628643852978454,
#  'for-large-groups': 7.399239543726236,
#  'pasta-salad': 3.4604409857328147,
#  'rosh-hashana': 3.6169590643274856,
#  'dips-summer': 3.477138018628281,
#  'chutneys': 3.585875470121187,
#  'mardi-gras-carnival': 3.6361323155216283,
#  'small-appliance': 5.300115207373272,
#  'desserts-easy': 3.496021220159151,
#  'high-protein': 5.11369904995403,
#  'beginner-cook': 6.336587498178639,
#  'bacon': 4.070652173913044,
#  'pork-loins': 3.9626355966251507,
#  'beef-barley-soup': 3.491121697704634,
#  'crab': 3.997991161108879,
#  'collard-greens': 3.4969670710571923,
#  'long-grain-rice': 3.9430959013131717,
#  'oatmeal': 3.5143468950749464,
#  'deer': 3.620274914089347,
#  'Throw the ultimate fiesta with this sopaipillas recipe from Food.com.': 3.502572898799314,
#  'camping': 3.951845906902087,
#  'quebec': 3.5476394849785406,
#  'chicken-crock-pot': 3.5911923556294143,
#  'microwave': 4.1469013006886,
#  'shrimp-main-dish': 3.435580204778157,
#  'medium-grain-rice': 3.4955414012738855,
#  'low-protein': 6.321211175277041,
#  'german': 4.052882703777336,
#  'european': 8.017847485127096,
#  'sandwiches': 4.782452707110242,
#  'beef-sauces': 3.5613805155089557,
#  'rolls-biscuits': 4.306923076923077,
#  'steam': 3.680192848533548,
#  'memorial-day': 3.5395956192080877,
#  'salads': 5.134328358208955,
#  'biscotti': 3.760486577181208,
#  'wedding': 3.8864646464646464,
#  'mashed-potatoes': 3.5778705636743213,
#  'pressure-canning': 3.5084015510555795,
#  'eggs-dairy': 7.614294810569882,
#  'tropical-fruit': 4.623804813715793,
#  'easter': 4.378021148036254,
#  'cinco-de-mayo': 3.5698513800424627,
#  'granola-and-porridge': 3.65389369592089,
#  'sole-and-flounder': 3.5709342560553634,
#  'irish': 3.814539446509707,
#  'cambodian': 3.5454545454545454,
#  'pasta': 6.553139506474468,
#  'dairy-free': 3.59174116645381,
#  'potatoes': 5.839573654003826,
#  'scottish': 3.8549459684123026,
#  'bean-soup': 3.4753191489361703,
#  'bar-cookies': 4.856353591160221,
#  'valentines-day': 4.313410534180052,
#  'cooking-mixes': 3.691397000789266,
#  'icelandic': 3.5506437768240344,
#  'pork-chops': 4.034415330465389,
#  'lamb-sheep': 4.160671462829736,
#  'kiwifruit': 3.5224006762468303,
#  'coconut': 4.234836702954899,
#  'georgian': 3.463996591393268,
#  'less_thansql:name_topics_of_recipegreater_than': 3.480118443316413,
#  'crock-pot-main-dish': 3.5287162162162162,
#  'greek': 4.306860551826995,
#  'dutch': 3.5644599303135887,
#  'seafood': 6.368445914029286,
#  'thai': 3.9503602882305846,
#  'spinach': 4.176563114431773,
#  'christmas': 5.921099820681411,
#  'freshwater-fish': 3.807895807895808,
#  'cake-fillings-and-frostings': 3.9232307077169133,
#  'mussels': 3.614659237033862,
#  'asian': 6.448625897499381,
#  'jewish-ashkenazi': 3.818065615679591,
#  'casseroles': 5.2317148125384145,
#  'romantic': 5.082747068676717,
#  'unprocessed-freezer': 3.461080391322841,
#  'fruit': 7.334788710431935,
#  'cabbage': 3.522120017520806,
#  'grains': 5.1455675498855085,
#  'equipment': 8.547858505288712,
#  '15-minutes-or-less': 4.97215602658974,
#  '30-minutes-or-less': 7.584102348993288,
#  'lime': 3.585912052117264,
#  'czech': 3.554549197200494,
#  'iranian-persian': 3.607769423558897,
#  'eggs': 5.952849291293028,
#  'salad-dressings': 3.778268876611418,
#  'appetizers': 6.265343325906421,
#  'side-dishes': 6.587577426015141,
#  'vegetables': 8.063007261853908,
#  'american': 7.5488386402091985,
#  'fall': 5.502732240437158,
#  'finger-food': 5.325137495956001,
#  'picnic': 5.113806528900868,
#  'spring': 4.538992408557626,
#  'summer': 5.30515759312321,
#  'vegetarian': 7.194960403167746,
#  'winter': 5.487782529016494,
#  'stove-top': 7.235509339495475,
#  'dietary': 8.81490041179931,
#  'copycat': 4.212328767123288,
#  'seasonal': 6.7724609375,
#  'brown-bag': 4.4414218353282555,
#  'inexpensive': 6.898605638072143,
#  'toddler-friendly': 4.470865611316942,
#  'novelty': 4.882054748225752,
#  'to-go': 6.451500205507604,
#  'presentation': 7.289039589442815,
#  'served-hot': 6.504420308158626,
#  '3-steps-or-less': 4.692612612612613,
#  'oven': 8.236817617866006,
#  'brazilian': 3.5971774193548387,
#  'pork': 6.402525252525253,
#  'canning': 4.017536534446764,
#  'chicken-livers': 3.491880341880342,
#  'wild-game': 3.715406856670797,
#  'puddings-and-mousses': 4.315850366370999,
#  'beans-side-dishes': 3.484076433121019,
#  'ontario': 3.765606121627064,
#  'savory': 6.187600213789417,
#  'low-sodium': 7.348299149574787,
#  'bass': 3.5762639245929733,
#  'meatballs': 3.6139493558418483,
#  'prepared-potatoes': 3.5012744265080715,
#  'oaxacan': 3.5063131313131315,
#  'saudi-arabian': 3.528085106382979,
#  'zucchini': 3.6469307792773185,
#  'roast-beef': 4.008603031544449,
#  'caribbean': 4.053483992467044,
#  'flat-shapes': 3.7735849056603774,
#  'healthy': 7.003417006176896,
#  'italian': 5.949116392443632,
#  'low-cholesterol': 6.585550266031924,
#  'low-saturated-fat': 6.459599123081741,
#  'low-calorie': 6.666480055983205,
#  'low-carb': 7.278217568947906,
#  'low-in-something': 7.987791260329041,
#  'green-yellow-beans': 3.950813323005422,
#  'tomatoes': 4.793125602312881,
#  'for-1-or-2': 5.390177104254153,
#  'nepalese': 3.4634146341463414,
#  'pasta-rice-and-grains': 7.693433199790977,
#  'white-rice': 3.869212022745735,
#  'lasagne': 3.5323617659665665,
#  'reynolds-wrap': 3.585774058577406,
#  'norwegian': 3.5625829279080055,
#  'egyptian': 3.6217484008528786,
#  'simply-potatoes': 3.6625666256662566,
#  'clear-soups': 3.689945309213294,
#  'soups-stews': 5.905304010349289,
#  'beans': 5.57037037037037,
#  '4-hours-or-less': 10.143281196483617,
#  'beef': 6.926345609065156,
#  'ground-beef': 5.525449558061567,
#  'burgers': 3.6307692307692307,
#  'high-calcium': 4.528154681139756,
#  'nuts': 5.579362670713202,
#  'snacks-kid-friendly': 3.5072402044293014,
#  'manicotti': 3.5980819529206625,
#  'heirloom-historical-recipes': 3.532888888888889,
#  'pheasant': 3.477076124567474,
#  'fudge': 3.7008443908323283,
#  'micro-melanesia': 3.5068980863373387,
#  'cajun': 3.92512077294686,
#  'breakfast-eggs': 3.482233502538071,
#  'cranberry-sauce': 3.4467265725288834,
#  'ham': 3.8986027944111776,
#  'laotian': 3.4915620943314583,
#  'wings': 3.7993226079593563,
#  'muffins': 4.300939306358382,
#  'ethiopian': 3.5024741340530814,
#  'whole-turkey': 3.602094240837696,
#  'cuban': 3.547847889678228,
#  'austrian': 3.5785374296841193,
#  'guatemalan': 3.5276360544217686,
#  'pickeral': 3.541795665634675,
#  'stir-fry': 4.213474343909127,
#  'roast-beef-main-dish': 3.5588361146769363,
#  'high-in-something-diabetic-friendly': 3.5584582441113493,
#  'belgian': 3.615027437737442,
#  'duck': 3.64715860899067,
#  'middle-eastern-main-dish': 3.5058977719528177,
#  'curries': 4.063112504900039,
#  'pies-and-tarts': 5.188724647645239,
#  'snacks-sweet': 3.4841337907375642,
#  'heirloom-historical': 5.043921293042867,
#  'honduran': 3.460813704496788,
#  'halloween-cocktails': 3.5407152089616543,
#  'baked-beans': 3.4943722943722944,
#  'trout': 3.5760069294066694,
#  'chicken-stews': 3.507725321888412,
#  'lunch': 6.7539217539217535,
#  'midwestern': 4.414990859232176,
#  'egg-free': 4.694909578030811,
#  'free-of-something': 5.728122565567385,
#  'number-of-servings': 7.837460830890529,
#  'potluck': 5.715945945945946,
#  'dips': 4.028925619834711,
#  'spreads': 3.870597243491577,
#  'cheese': 6.559729351376575,
#  'sweet-sauces': 3.5938538205980066,
#  'somalian': 3.491532599491956,
#  'shellfish': 5.460049170251998,
#  'squash': 4.742602495543672,
#  'libyan': 3.412336290663287,
#  'chilean': 3.5560727888277612,
#  'pitted-fruit': 4.150078369905956,
#  'chowders': 3.865979381443299,
#  'southern-united-states': 5.296809151113787,
#  'no-shell-fish': 3.603319502074689,
#  'steaks': 3.9254658385093166,
#  'turkey-burgers': 3.5004299226139297,
#  'kwanzaa': 3.6619246861924686,
#  'irish-st-patricks-day': 3.489425981873112,
#  'infant-baby-friendly': 3.647009267059815,
#  'celebrity': 3.8279967159277506,
#  'costa-rican': 3.5415936952714535,
#  'marinara-sauce': 3.532138172278094,
#  'macaroni-and-cheese': 3.5088832487309647,
#  'bisques-cream-soups': 4.1784358390280945,
#  'cantonese': 3.574712643678161,
#  'scandinavian': 3.836033188463058,
#  'french': 4.463657230298393,
#  'hanukkah': 3.738551207327227,
#  'chinese-new-year': 3.5453005927180357,
#  'pumpkin-bread': 3.5304311073541843,
#  '1-day-or-more': 4.603414823438106,
#  'amish-mennonite': 3.592436974789916,
#  'mixer': 4.31965272296764,
#  'blueberries': 3.9197577592732777,
#  'spanish': 3.8452924097884695,
#  'pressure-cooker': 3.6937051119560627,
#  'birthday': 3.5455696202531644,
#  'low-fat': 5.847093023255814,
#  'african': 4.275036818851252,
#  'turkey': 4.311978771796816,
#  'gluten-free': 4.759198423127464,
#  'pork-loin': 3.5212990299451707,
#  'main-dish-beef': 3.4778534923339013,
#  'water-bath': 3.767343485617597,
#  'lactose': 4.600471221810838,
#  'british-columbian': 3.649686847599165,
#  'main-dish-pork': 3.49936088623775,
#  'ragu-recipe-contest': 3.5581000848176423,
#  'pizza': 4.083860759493671,
#  'mahi-mahi': 3.5884536082474225,
#  'creole': 3.792292089249493,
#  'swedish': 3.513535031847134,
#  'mango': 3.653378094838439,
#  'pork-crock-pot': 3.537381247418422,
#  'oamc-freezer-make-ahead': 5.009786787836421,
#  'crock-pot-slow-cooker': 4.754320987654321,
#  'bear': 3.490773286467487,
#  'stews': 4.012529365700861,
#  'condiments-etc': 4.821279916753382,
#  'tuna': 3.7663702506063057,
#  'brewing': 3.5058568329718005,
#  'veggie-burgers': 3.5141752577319587,
#  'served-hot-new-years': 3.5277171540811874,
#  'pork-ribs': 3.6905151267375307,
#  'rolled-cookies': 3.8099343185550083,
#  'indonesian': 3.5633744855967078,
#  'lettuces': 3.6854066985645932,
#  'lentils': 3.949711459192086,
#  'breads': 6.927224371373308,
#  'tarts': 3.734845360824742,
#  'south-american': 3.8887996788438377,
#  'black-bean-soup': 3.451804670912951,
#  'food-processor-blender': 4.5707450444292546,
#  'polish': 3.6470109800732007,
#  'punch': 3.5167731629392973,
#  'puerto-rican': 3.5209158960810214,
#  'non-alcoholic': 3.5488754325259517,
#  'superbowl': 3.9948269001193792,
#  'pakistani': 3.5227172474636084,
#  'jewish-sephardi': 3.567396798652064,
#  'mongolian': 3.4834324553950724,
#  'chick-peas-garbanzos': 3.9178571428571427,
#  'beef-sausage': 3.702725020644096,
#  'pasta-rice-and-grains-elbow-macaroni': 3.4836206896551722,
#  'vegan': 5.179083885209713,
#  '5-ingredients-or-less': 5.380599144079886,
#  'hunan': 3.5023902651021297,
#  'chinese': 4.289452815226011,
#  'salmon': 4.1831362075543685,
#  'fish': 5.187825022942796,
#  'saltwater-fish': 4.710543549443353,
#  'baja': 3.5094017094017094,
#  'herb-and-spice-mixes': 3.5357580711074785,
#  'black-beans': 3.9011201235998456,
#  'pot-roast': 3.4861227922624054,
#  'salsas': 3.5974454058508445,
#  'breakfast': 6.095641646489105,
#  'kosher': 4.759171195652174,
#  'mushroom-soup': 3.512788259958071,
#  'greens': 4.6606460576589095,
#  'a1-sauce': 3.491460290350128,
#  'whole-chicken': 3.9904006677796326,
#  'cakes': 6.741095890410959,
#  'shakes': 3.5344827586206895,
#  'ramadan': 3.584516129032258,
#  'halloween-cupcakes': 3.4793771043771042,
#  'moose': 3.4884516680923867,
#  'finnish': 3.516470109800732,
#  'dips-lunch-snacks': 3.514792899408284,
#  'jellies': 3.612040133779264,
#  'cherries': 3.633609958506224,
#  'turkish': 3.650526315789474,
#  'palestinian': 3.4768637532133675,
#  'pasta-shells': 3.724738675958188,
#  'south-west-pacific': 4.468449931412894,
#  'quiche': 3.5348837209302326,
#  'breakfast-potatoes': 3.500658183413778,
#  'lemon': 4.115906288532676,
#  'strawberries': 4.0979576399394855,
#  'english': 4.128981517892253,
#  'for-large-groups-holiday-event': 3.539156626506024,
#  'duck-breasts': 3.49009083402147,
#  'pies': 4.61171204774338,
#  'vietnamese': 3.612357173085061,
#  'drop-cookies': 4.375138325341203,
#  'ecuadorean': 3.5352767215885086,
#  'polynesian': 3.53684643886373,
#  'snacks': 4.966421207658321,
#  'szechuan': 3.576923076923077,
#  'citrus': 4.617354196301565,
#  'gifts': 5.5901273885350315,
#  'broccoli': 4.106048703849175,
#  'bread-machine': 3.697810789679437,
#  'new-zealand': 3.650433347090384,
#  'technique': 5.407736539466806,
#  'no-cook': 3.957138253303255,
#  'tempeh': 3.4715374271627075,
#  'carrots': 4.355365763089491,
#  'cauliflower': 3.756312625250501,
#  'mothers-day': 3.480291345329906,
#  'northeastern-united-states': 4.281144147534814,
#  'frozen-desserts': 4.060490045941807,
#  'brown-rice': 3.6068908260689083,
#  'tilapia': 3.5551181102362204,
#  'lobster': 3.6033163265306123,
#  'spaghetti-sauce': 3.487223168654174,
#  'rosh-hashanah': 3.5582362728785357,
#  'pacific-northwest': 3.8091603053435112,
#  'scallops': 3.6803519061583576,
#  'octopus': 3.4690514469453375,
#  'roast-beef-comfort-food': 3.5491329479768785,
#  'cupcakes': 3.9383730484798685,
#  'halloween': 3.7860169491525424,
#  'whole-duck': 3.58500837520938,
#  'labor-day': 3.524536082474227,
#  'pasta-elbow-macaroni': 3.4500677812923635,
#  'indian': 4.393916913946588,
#  'side-dishes-beans': 3.486982501067008,
#  'stocks': 3.6719082022949427,
#  'bananas': 4.007698229407237,
#  'sweet': 6.114332603938731,
#  'lamb-sheep-main-dish': 3.5026246719160103,
#  'hidden-valley-ranch': 3.5413410119292474,
#  'sauces': 4.232761520349815,
#  'stews-poultry': 3.4736186123805566,
#  'apples': 4.768770764119601,
#  'main-dish-pasta': 3.464943032427695,
#  'moroccan': 3.778894472361809,
#  'danish': 3.590633130962706,
#  'korean': 3.583442265795207,
#  'pork-loins-roast': 3.552133743950726,
#  'meatloaf': 3.531678082191781,
#  'grilling': 4.91219678852067,
#  'chard': 3.5674278328306763,
#  'cobblers-and-crisps': 3.953738124741842,
#  'canadian': 4.777970211291999,
#  'berries': 5.004846526655896,
#  'garnishes': 3.54593711719069,
#  'raspberries': 3.8025695931477514,
#  'peaches': 3.8216432865731464,
#  'penne': 3.930344275420336,
#  'oranges': 3.9122392758756397,
#  'beef-crock-pot': 3.4835782195332756,
#  'gumbo': 3.6229221347331584,
#  'cheesecake': 4.539181286549708,
#  'ravioli-tortellini': 3.780546623794212,
#  'quail': 3.5585470085470083,
#  'super-bowl': 3.5994283380971823,
#  'chicken-stew': 3.514247551202137,
#  'middle-eastern': 4.215473887814313,
#  'spicy': 5.552694610778443,
#  'asparagus': 4.04756242568371,
#  'japanese': 3.8176638176638176,
#  'venezuelan': 3.53907900295733,
#  'april-fools-day': 3.5523769457299115,
#  'goose': 3.4743856726364015,
#  'beef-kidney': 3.5156529516994635,
#  'beverages': 3.8725617685305593,
#  'nigerian': 3.4625850340136055,
#  'rabbit': 3.5268817204301075,
#  'argentine': 3.583696599825632,
#  'pineapple': 3.962044344231492,
#  'soul': 3.5596638655462183,
#  'broil': 4.021350931677019,
#  'smoothies': 3.484174830444612,
#  'mushrooms': 4.626338329764454,
#  'pears': 3.7868104520945667,
#  'omelets-and-frittatas': 3.9701612903225807,
#  'onions': 5.087678512122219,
#  'south-african': 3.6291161178509532,
#  'cocktails': 3.589788120875304,
#  'high-fiber': 3.562082777036048,
#  'college': 3.547939262472885,
#  'st-patricks-day': 3.7040485829959513,
#  'main-dish-chicken': 3.5157531290461805,
#  'bok-choys': 3.514359194170596,
#  'lasagna': 4.133744855967078,
#  'soy-tofu': 3.9559748427672954,
#  'oysters': 3.5905612244897958,
#  'rice': 5.009661835748792,
#  'halloween-cakes': 3.504212299915754,
#  'beef-organ-meats': 3.504047720494248,
#  'portuguese': 3.6469601677148846,
#  'pumpkin': 3.51228654727197,
#  'yeast': 5.036486007793128,
#  'roast': 4.121739130434783,
#  'iraqi': 3.5634328358208953,
#  'avocado': 3.454701588664663,
#  'sudanese': 3.436826218197499,
#  'diabetic': 4.852136489394405,
#  'crusts-pastry-dough-2': 3.707567336468576,
#  'simply-potatoes2': 3.537241075363596,
#  'pancakes-and-waffles': 4.194099378881988,
#  'russian': 3.788874841972187,
#  'steak': 3.9223492313756405,
#  'new-years': 4.401363120030291,
#  'perch': 3.524782608695652,
#  'desserts-fruit': 3.5174443043295502,
#  'welsh': 3.62882096069869,
#  'chocolate-chip-cookies': 3.5580204778157,
#  'stuffings-dressings': 3.706882255389718,
#  'beef-ribs': 3.6120689655172415,
#  'dehydrator': 3.548467274233637,
#  'central-american': 4.0900079302141155,
#  'coffee-cakes': 3.978887535525782,
#  'halibut': 3.566013071895425,
#  'bread-pudding': 3.5257019438444925,
#  'tex-mex': 4.004428341384863,
#  'fathers-day': 3.483050847457627,
#  'lebanese': 3.687129551227773,
#  'scones': 3.8892068683565,
#  'catfish': 3.574697754749568,
#  'elk': 3.50148493848112,
#  'eggplant': 3.6312607944732296,
#  'thanksgiving': 4.903798367057153,
#  'jams-and-preserves': 3.8541070698814877,
#  'fillings-and-frostings-chocolate': 3.477203647416413,
#  'plums': 3.5756536648092583,
#  'malaysian': 3.561306745863386,
#  'crawfish': 3.527265100671141,
#  'marinades-and-rubs': 3.574265289912629,
#  'deep-fry': 4.052170283806344,
#  'chocolate': 6.255373303167421,
#  'hawaiian': 3.619672131147541,
#  'chili': 3.9473893981666004,
#  'squid': 3.476313522825151,
#  'cod': 3.6464981351015333,
#  'turkey-breasts': 3.616967660646787,
#  'beijing': 3.5068201193520885,
#  'native-american': 3.5321180555555554,
#  'savory-sauces': 3.8540604158493528,
#  'main-dish-seafood': 3.4357298474945535,
#  'swiss': 3.6045415595544132,
#  'southwestern-united-states': 4.507175358767938,
#  'yams-sweet-potatoes': 4.008624068992552,
#  'ice-cream': 3.562366964665815,
#  'melons': 3.5982215036378333,
#  'sourdough': 3.579298089737894,
#  'hungarian': 3.6426778242677824,
#  'nut-free': 3.5928118393234674,
#  'short-grain-rice': 3.6549479166666665,
#  'shrimp': 4.944992947813822,
#  'congolese': 3.5593869731800765,
#  'peanut-butter': 3.5862516212710767,
#  'brownies': 3.951357924604783,
#  'papaya': 3.5784105397365065,
#  'sugar-cookies': 3.560016556291391,
#  'very-low-carbs': 5.386304536261196,
#  'leftovers': 3.625362619146291,
#  'elbow-macaroni': 4.038051750380517,
#  'hand-formed-cookies': 4.2762691853600945,
#  'clams': 3.6342857142857143,
#  'from-scratch': 4.6136445242369835,
#  'pot-pie': 3.5333059210526314,
#  'corn': 4.083783783783784,
#  'artichoke': 3.547768043387568,
#  'smoker': 3.5210643015521064,
#  'beef-liver': 3.56137339055794,
#  'eggs-breakfast': 3.4931798806479115,
#  'angolan': 3.5002105263157897}

# %% [markdown]
# 3. Напишите функцию, которая считает среднее значение количества шагов для каждого тэга по всем файлам, полученным в задаче 1, и возвращает результат в виде словаря. Не используйте параллельных вычислений. При реализации выделите функцию, которая объединяет результаты обработки отдельных файлов. Модифицируйте код из задачи 2 таким образом, чтобы получить результат, имея результаты обработки отдельных файлов. Определите, за какое время задача решается для всех файлов.

# %%
def merge_df(file, prev_df = pd.DataFrame()):
    df = pd.read_csv(file, sep=";")
    df = df.append(prev_df)
    return df

# %%
def mean_step_df(df):
    tags_dict = {}
    df_tags = df.groupby('tags').mean()["n_steps"]
    df = df.dropna()
    df_tags = df_tags.dropna()
    for tag in df["tags"]:
        if tag not in tags_dict:
            tags_dict[tag] = df_tags[tag]
    return tags_dict

# %%
# %%time
df = merge_df('./output/id_tag_nsteps_1.csv')
for i in range(2, 9):
    df = merge_df('./output/id_tag_nsteps_' + str(i) + '.csv', df)
tags_dict = mean_step_df(df)
tags_dict
# Out:
# Wall time: 14.1 s
# {'middle-eastern': 4.191139303236038,
#  'lamb-sheep': 4.130016786204791,
#  'granola-and-porridge': 3.7370038545681843,
#  'south-african': 3.6286164034087824,
#  'pork-ribs': 3.711184495452577,
#  'chilean': 3.5288842429577465,
#  'greek': 4.349770081205362,
#  'low-sodium': 7.3863798933541425,
#  'yams-sweet-potatoes': 4.005262620069487,
#  'roast': 4.020509341404864,
#  'herb-and-spice-mixes': 3.552204547880858,
#  'jellies': 3.5721814724259713,
#  'salads': 5.062135863099777,
#  'italian': 5.8739571150097465,
#  '5-ingredients-or-less': 5.345920719916704,
#  'preparation': 9.293416400880012,
#  'to-go': 6.433847655720368,
#  'bisques-cream-soups': 4.132540995938017,
#  'shakes': 3.525634933206611,
#  'south-american': 3.941121832911915,
#  'welsh': 3.5899640796778054,
#  'poultry': 7.673893983554892,
#  'low-carb': 7.247922207446808,
#  '30-minutes-or-less': 7.610132158590308,
#  'time-to-make': 9.27850778138217,
#  'course': 9.274686706181202,
#  'main-ingredient': 9.315210297605468,
#  'cuisine': 9.1700252580716,
#  'occasion': 9.136277173913044,
#  'north-american': 8.187233786366852,
#  'for-large-groups': 7.293004554911994,
#  'breakfast': 6.098151629072682,
#  'fruit': 7.310792710151398,
#  'american': 7.575099698868723,
#  'easy': 7.253311258278146,
#  'fall': 5.555992292870906,
#  'grains': 5.206610190710679,
#  'seasonal': 6.8062785416614675,
#  'brown-bag': 4.355984628362545,
#  'apples': 4.85682676038006,
#  'berries': 4.987671744634926,
#  'pasta-rice-and-grains': 7.771835927957539,
#  'brunch': 6.871661962657403,
#  'number-of-servings': 7.848588714912623,
#  'super-bowl': 3.582380485680061,
#  'mongolian': 3.5210330876240095,
#  'breakfast-potatoes': 3.501639891044527,
#  'melons': 3.6164650184113625,
#  'somalian': 3.520300016305234,
#  'raspberries': 3.9046359017781542,
#  'snacks-kid-friendly': 3.5009977827050998,
#  'oysters': 3.568528198074278,
#  'punch': 3.5956371512557372,
#  'crawfish': 3.52754767331962,
#  'scallops': 3.766795657314845,
#  'perch': 3.494737416153133,
#  'artichoke': 3.4960065645514224,
#  'weeknight': 7.413649806241077,
#  'lemon': 4.108630574864275,
#  'eggs-breakfast': 3.4854300315320215,
#  'marinara-sauce': 3.522765969132751,
#  'amish-mennonite': 3.560696788241698,
#  'tomatoes': 4.863886342804766,
#  'a1-sauce': 3.5280419809773695,
#  'southern-united-states': 5.231357927786499,
#  'chicken-stew': 3.480013380163907,
#  'bass': 3.5415725384318697,
#  'eggs': 5.909033055066821,
#  'penne': 3.9567099567099566,
#  'strawberries': 4.110803597904517,
#  'french': 4.472535520726527,
#  'gifts': 5.5754301720688275,
#  'fudge': 3.7261221016804935,
#  'malaysian': 3.57388691614313,
#  'swiss': 3.6533907427341226,
#  'for-1-or-2': 5.473579840874465,
#  'cheese': 6.524772252655791,
#  'nut-free': 3.580711763107851,
#  'nigerian': 3.485750232481812,
#  'beans-side-dishes': 3.5152363696260913,
#  'side-dishes': 6.676337302292518,
#  'quiche': 3.5354525921436837,
#  'halloween-cupcakes': 3.5033479692645444,
#  'lamb-sheep-main-dish': 3.496599015650058,
#  'no-shell-fish': 3.562639516524201,
#  'micro-melanesia': 3.5141301957334505,
#  'hunan': 3.5117907354506244,
#  'high-protein': 5.007946914610402,
#  'cauliflower': 3.85839378238342,
#  'stocks': 3.6284188379996762,
#  'wings': 3.6984937995635745,
#  'heirloom-historical-recipes': 3.5178403496155335,
#  'ontario': 3.737262156448203,
#  'cooking-mixes': 3.609224057338735,
#  'spaghetti-sauce': 3.508873435326843,
#  'irish-st-patricks-day': 3.518823333147973,
#  'puerto-rican': 3.540382513661202,
#  'low-calorie': 6.726496822286123,
#  'lasagne': 3.5145545102379634,
#  'cabbage': 3.5122165004930426,
#  'ramadan': 3.6026196087028004,
#  '1-day-or-more': 4.459439233685891,
#  'eggs-dairy': 7.623189911287474,
#  'lettuces': 3.7256257199706777,
#  'stews': 4.120702672773946,
#  'costa-rican': 3.513296565281494,
#  'pork': 6.4437282286681645,
#  'savory-sauces': 3.812120306742356,
#  'zucchini': 3.58697079094191,
#  'kiwifruit': 3.5339135164536306,
#  'chocolate-chip-cookies': 3.519182286528554,
#  'soups-stews': 5.9352367453005295,
#  'cobblers-and-crisps': 3.910389202762084,
#  'citrus': 4.549448073890516,
#  'chutneys': 3.5558799675587998,
#  'pressure-canning': 3.538096551724138,
#  'mahi-mahi': 3.5369613771313397,
#  'dips-lunch-snacks': 3.507624309392265,
#  'plums': 3.5635477155691904,
#  'czech': 3.5725535547111624,
#  'desserts': 9.023456628905357,
#  'canadian': 4.764779480763216,
#  'beginner-cook': 6.326035834266517,
#  'holiday-event': 8.308282439870316,
#  'cookies-and-brownies': 6.727248893986564,
#  '4-hours-or-less': 10.065263998344003,
#  'mushrooms': 4.6644879149816605,
#  'savory-pies': 4.298328243879716,
#  'nuts': 5.503219139972975,
#  'flat-shapes': 3.83120286677007,
#  'ice-cream': 3.5219947855993787,
#  'main-dish-seafood': 3.5055491771909684,
#  'main-dish-pork': 3.513633340722678,
#  'pork-crock-pot': 3.510396975425331,
#  'manicotti': 3.614364640883978,
#  'avocado': 3.531110989071338,
#  'goose': 3.5103463538784996,
#  'april-fools-day': 3.5103864194773284,
#  'less_thansql:name_topics_of_recipegreater_than': 3.5148095133230566,
#  'mashed-potatoes': 3.52792349726776,
#  'seafood': 6.374263556570879,
#  'short-grain-rice': 3.689175985235045,
#  'hidden-valley-ranch': 3.56636587366694,
#  'desserts-easy': 3.5050172725777267,
#  'unprocessed-freezer': 3.5198803854247425,
#  'lentils': 3.9327888466940646,
#  'gelatin': 3.7341488168367074,
#  'japanese': 3.788570832681579,
#  'sole-and-flounder': 3.580126803672934,
#  'savory': 6.042196451026967,
#  'beef-sauces': 3.5037515745659675,
#  'potatoes': 5.894798342834886,
#  'vegetables': 8.089443895926909,
#  'vegan': 5.190527141736215,
#  'vegetarian': 7.214044577077311,
#  'dietary': 8.846635478817191,
#  'carrots': 4.3147672093687515,
#  'greens': 4.658566221142163,
#  '3-steps-or-less': 4.7288194719733605,
#  'duck-breasts': 3.5412215387935686,
#  'valentines-day': 4.472800344481126,
#  'native-american': 3.5655307994757535,
#  'namibian': 3.5042895887529752,
#  'new-zealand': 3.6738208797032326,
#  'romantic': 5.15583577207781,
#  'bacon': 4.10665269251884,
#  'roast-beef': 4.015181449516481,
#  'biscotti': 3.7415754686314875,
#  'bar-cookies': 4.8392488262910796,
#  '15-minutes-or-less': 4.986565505243319,
#  'lunch': 6.678860028860029,
#  'main-dish': 9.442468712421503,
#  'european': 8.016243513066952,
#  'english': 4.146556529671109,
#  'meat': 8.918907625325192,
#  'pacific-northwest': 3.7700684505289357,
#  'moroccan': 3.8259548383716666,
#  'smoker': 3.581018647369886,
#  'chili': 3.9434637885818034,
#  'lebanese': 3.6328620185275478,
#  'turkish': 3.620761690502973,
#  'meatballs': 3.541812330059375,
#  'sugar-cookies': 3.537796619501184,
#  'inexpensive': 6.93097739322388,
#  'dutch': 3.5777420428080293,
#  'thai': 3.899144946945503,
#  'long-grain-rice': 3.9543551305246836,
#  'turkey': 4.414412664497645,
#  'tuna': 3.8548345860817097,
#  'szechuan': 3.553976808753879,
#  'low-protein': 6.2924007830574835,
#  'dairy-free': 3.5595883286801335,
#  'coconut': 4.106659284240197,
#  'jewish-ashkenazi': 3.794318242844101,
#  'papaya': 3.545848890841204,
#  'novelty': 4.800665178766794,
#  'pickeral': 3.4951028942445252,
#  'reynolds-wrap': 3.565602449158102,
#  'saudi-arabian': 3.531842893598136,
#  '60-minutes-or-less': 9.413654300607185,
#  'healthy': 7.080629201214727,
#  'rice': 5.126250103314323,
#  'low-cholesterol': 6.621511553915241,
#  'low-saturated-fat': 6.505154015290581,
#  'healthy-2': 6.384162244806188,
#  'low-in-something': 8.057098661645034,
#  'white-rice': 3.8467779684818226,
#  'southwestern-united-states': 4.4924616164876205,
#  'rolled-cookies': 3.933474801061008,
#  'free-of-something': 5.713046100241222,
#  'caribbean': 3.9957735849056606,
#  'pancakes-and-waffles': 4.1733998419597,
#  'chicken': 7.325226860254084,
#  'pasta': 6.5836000512098325,
#  'kid-friendly': 7.095590014296712,
#  'wedding': 3.921485635680652,
#  'ham-and-bean-soup': 3.508423254789694,
#  'crock-pot-slow-cooker': 4.700854008985308,
#  'drop-cookies': 4.393322360686574,
#  'pumpkin': 3.559947586809347,
#  'comfort-food': 7.501074976803132,
#  'peruvian': 3.5665068569517224,
#  'brownies': 3.9802875816993466,
#  'heirloom-historical': 5.063579485371871,
#  'blueberries': 3.9650378038260516,
#  'very-low-carbs': 5.320270764727406,
#  'jewish-sephardi': 3.5652531229454305,
#  'mussels': 3.5937723103959582,
#  'bread-machine': 3.793686699912601,
#  'ecuadorean': 3.516626558739882,
#  'spring': 4.533591324303649,
#  'summer': 5.304315317239906,
#  'stove-top': 7.2552827380952385,
#  'ravioli-tortellini': 3.7443362324878913,
#  'asparagus': 4.047421217955213,
#  'equipment': 8.574089581965914,
#  'presentation': 7.177265370270461,
#  'served-hot': 6.44635292560233,
#  'shrimp': 4.860226515656229,
#  'from-scratch': 4.745889101338432,
#  'curries': 4.056318540535001,
#  'steam': 3.6812774622226985,
#  'smoothies': 3.4916926794884704,
#  'beef-crock-pot': 3.4955118673935788,
#  'asian': 6.445874984183222,
#  'colombian': 3.5359842260926717,
#  'served-hot-new-years': 3.5059235775070916,
#  'indonesian': 3.582323121005069,
#  'passover': 3.658676110051757,
#  'veal': 3.6804319513783375,
#  'simply-potatoes2': 3.508810081409613,
#  'Throw the ultimate fiesta with this sopaipillas recipe from Food.com.': 3.5116482077581974,
#  'portuguese': 3.6449111470113085,
#  'belgian': 3.573172048817367,
#  'pennsylvania-dutch': 3.5471966710468683,
#  'cajun': 3.910293213040804,
#  'rolls-biscuits': 4.37720346579026,
#  'coffee-cakes': 4.042268842268842,
#  'broccoli': 4.107340720221607,
#  'easter': 4.4522793071298885,
#  'vietnamese': 3.6583629893238436,
#  'oamc-freezer-make-ahead': 5.101522613292369,
#  'garnishes': 3.6137860853730386,
#  'collard-greens': 3.5319676193622995,
#  'barbecue': 4.596669048044293,
#  'baja': 3.53721200066302,
#  'quail': 3.502773547966065,
#  'high-fiber': 3.518181818181818,
#  'side-dishes-beans': 3.501832111925383,
#  'whitefish': 3.514734127201888,
#  'chinese': 4.309035268148297,
#  'indian': 4.467002398081535,
#  'dinner-party': 8.233824137497079,
#  'small-appliance': 5.241089441829186,
#  'pitted-fruit': 4.122290471597543,
#  'sudanese': 3.496088407462115,
#  'beef-barley-soup': 3.498673006745549,
#  'no-cook': 3.9530264947051794,
#  'pies-and-tarts': 5.233969866853539,
#  'pies': 4.679968336747998,
#  'beef-liver': 3.550352718991279,
#  'pheasant': 3.520208171852508,
#  'sweet': 6.063357532390843,
#  'superbowl': 4.055649492739208,
#  'eggplant': 3.5645143548564513,
#  'midwestern': 4.399375384469787,
#  'icelandic': 3.502124183006536,
#  'scandinavian': 3.953488372093023,
#  'spreads': 3.84343757695149,
#  'chowders': 3.8468745120491334,
#  'oranges': 3.8910941736150186,
#  'tarts': 3.7580992358196106,
#  'whole-duck': 3.537125152152263,
#  'chard': 3.586361401016338,
#  'pork-loin': 3.487238597068994,
#  'fillings-and-frostings-chocolate': 3.5121640343585483,
#  'grilling': 4.793819410912603,
#  'mexican': 5.302344316442439,
#  'scottish': 3.7987558485750745,
#  'corn': 4.076911822083496,
#  'frozen-desserts': 4.038928837093975,
#  'medium-grain-rice': 3.550438716006322,
#  'baking': 3.6306821245618766,
#  'russian': 3.7004585918532507,
#  'halibut': 3.6225172830023045,
#  'high-in-something-diabetic-friendly': 3.5027038958172385,
#  'brazilian': 3.5924736363149723,
#  'infant-baby-friendly': 3.6132161914515173,
#  'winter': 5.496159515866243,
#  'taste-mood': 8.455551143132695,
#  'clear-soups': 3.7017780172413794,
#  'technique': 5.330086325618891,
#  'breads': 7.1460181064907164,
#  'quick-breads': 5.059023265562775,
#  'cocktails': 3.61964958970947,
#  'cod': 3.6570873995794466,
#  'salmon': 4.205071502285125,
#  'lactose': 4.548202468252549,
#  'low-fat': 5.944445829697045,
#  'duck': 3.5997391020763128,
#  'beans': 5.485727808927401,
#  'potluck': 5.740600062724327,
#  'californian': 3.74143203627544,
#  'black-beans': 3.93185306456564,
#  'northeastern-united-states': 4.325447229359577,
#  'spinach': 4.175668854114083,
#  'stuffings-dressings': 3.717682339081075,
#  'finger-food': 5.2388437512758745,
#  'brown-rice': 3.719026197406721,
#  'mardi-gras-carnival': 3.6024259489900903,
#  'sauces': 4.232691901036159,
#  'halloween-cocktails': 3.514611821790913,
#  'macaroni-and-cheese': 3.5318565632196512,
#  'turkey-breasts': 3.6294220093610536,
#  'pasta-elbow-macaroni': 3.4888071985076263,
#  'ham': 4.030267694179679,
#  'snacks': 4.974996093139553,
#  'copycat': 4.257255936675461,
#  'iraqi': 3.5319321813552897,
#  'memorial-day': 3.526248754014841,
#  'leftovers': 3.628175895765472,
#  'angolan': 3.4931362780914426,
#  'turkey-burgers': 3.4884499314128945,
#  'pizza': 4.149197643713183,
#  'rabbit': 3.5241744307844973,
#  'high-calcium': 4.515901675005439,
#  'peppers': 4.517914691943128,
#  'thanksgiving': 4.958787389569039,
#  'chicken-breasts': 5.757057608446178,
#  'bread-pudding': 3.5062297601405126,
#  'oatmeal': 3.500110460620789,
#  'appetizers': 6.231012410189419,
#  'clams': 3.635291572000433,
#  'beverages': 3.899079152278421,
#  'kosher': 4.825991189427313,
#  'beef-organ-meats': 3.5562640866362485,
#  'mushroom-soup': 3.4856729538752576,
#  'african': 4.372096337466154,
#  'rosh-hashana': 3.6900091857135138,
#  'irish': 3.7723708239338274,
#  'served-cold': 4.911621189054144,
#  'pot-pie': 3.5088093674764718,
#  'roast-beef-comfort-food': 3.498625316177279,
#  'shellfish': 5.401717519490284,
#  'breakfast-casseroles': 3.506533222129552,
#  'freshwater-fish': 3.8349246764269043,
#  'south-west-pacific': 4.414301359861276,
#  'catfish': 3.5580889154921915,
#  'soul': 3.5588170985022414,
#  'cranberry-sauce': 3.495701058201058,
#  'microwave': 4.0819245134656965,
#  'bear': 3.494859606455892,
#  'steak': 3.92369043943604,
#  'central-american': 4.059544571229259,
#  'fathers-day': 3.5008259911894273,
#  'onions': 5.003155255878285,
#  'brewing': 3.534414513468939,
#  'stir-fry': 4.167118746232671,
#  'bean-soup': 3.506754893851668,
#  'spanish': 3.8625397321661197,
#  'ethiopian': 3.509815849140076,
#  'spaghetti': 4.0825152293208475,
#  'mixer': 4.301563056870831,
#  'oaxacan': 3.5224962918200298,
#  'polynesian': 3.553561718325177,
#  'cantonese': 3.5635441362959694,
#  'diabetic': 4.895048701298701,
#  'peaches': 3.778925836567712,
#  'cherries': 3.707792207792208,
#  'one-dish-meal': 7.003855449418805,
#  'british-columbian': 3.718204621871164,
#  'veggie-burgers': 3.512272148041443,
#  'marinades-and-rubs': 3.5826751592356687,
#  'pumpkin-bread': 3.509180673434293,
#  'congolese': 3.4968992681155373,
#  'spicy': 5.450922706606044,
#  'swedish': 3.6309587004989914,
#  'beef': 6.937072852565011,
#  'german': 4.057022013860579,
#  'hawaiian': 3.625,
#  'labor-day': 3.5164488258750555,
#  'jams-and-preserves': 3.850592261121348,
#  'dips-summer': 3.484745194456862,
#  'pot-roast': 3.488254387412664,
#  'georgian': 3.4969924397108327,
#  'quebec': 3.5783718768793396,
#  'simply-potatoes': 3.6358264485418834,
#  'crusts-pastry-dough-2': 3.6874797450577943,
#  'honduran': 3.5143279011265447,
#  'oven': 8.348988512757956,
#  'hanukkah': 3.7728091554519443,
#  'mothers-day': 3.558894362342638,
#  'lobster': 3.59012222775289,
#  'condiments-etc': 4.7830466911886536,
#  'food-processor-blender': 4.479378963481303,
#  'ragu-recipe-contest': 3.5131040583877033,
#  'elbow-macaroni': 4.0664339254543584,
#  'puddings-and-mousses': 4.324805667617829,
#  'lime': 3.6746153439433193,
#  'chicken-livers': 3.544458514562572,
#  'pork-loins': 4.010719834282755,
#  'water-bath': 3.7291033434650456,
#  'bananas': 4.000644649409898,
#  'birthday': 3.6248698416178002,
#  'camping': 3.934283942963422,
#  'sandwiches': 4.794260578131546,
#  'canning': 3.9452296819787986,
#  'elk': 3.5071385591597832,
#  'pork-chops': 4.036843453753523,
#  'pressure-cooker': 3.667061547574175,
#  'dehydrator': 3.5021339461588967,
#  'dips': 4.025779588944012,
#  'breakfast-eggs': 3.510853437379788,
#  'whole-chicken': 4.0393326645900425,
#  'freezer': 4.033042234819468,
#  'kwanzaa': 3.6018448997103936,
#  'muffins': 4.305949143647727,
#  'pork-loins-roast': 3.51767830465335,
#  'celebrity': 3.7695260436103855,
#  'for-large-groups-holiday-event': 3.5172128890112915,
#  'tropical-fruit': 4.590361445783133,
#  'ground-beef': 5.532396415715708,
#  'tilapia': 3.6113482842475007,
#  'tempeh': 3.527434613244296,
#  'scones': 3.8034052453468696,
#  'palestinian': 3.5308247479477717,
#  'fish': 5.300345857569565,
#  'hungarian': 3.664425862163196,
#  'mango': 3.681424395429179,
#  'orange-roughy': 3.513425052701653,
#  'chocolate': 6.202489956932431,
#  'cake-fillings-and-frostings': 3.9406652527029125,
#  'casseroles': 5.341411232256737,
#  'tex-mex': 3.951607133731923,
#  'yeast': 5.179112222274636,
#  'high-in-something': 5.465606147416669,
#  'cinco-de-mayo': 3.5550013702384216,
#  'snacks-sweet': 3.4965144163738775,
#  'pork-sausage': 4.256068444090729,
#  'sourdough': 3.5868755903761738,
#  'danish': 3.5856840045654654,
#  'norwegian': 3.5663843361566383,
#  'egg-free': 4.786737262390417,
#  'cupcakes': 3.9464164357781377,
#  'candy': 4.229612689762553,
#  'main-dish-chicken': 3.5083209754490032,
#  'pineapple': 3.9677019864269085,
#  'burgers': 3.5708975620421994,
#  'polish': 3.6785428556189665,
#  'cakes': 6.733708189158016,
#  'squash': 4.694080622020642,
#  'pasta-rice-and-grains-elbow-macaroni': 3.491643223564455,
#  'toddler-friendly': 4.594735231098867,
#  'grapes': 3.5634223090277777,
#  'pasta-shells': 3.697942342728539,
#  'salsas': 3.605928790075721,
#  'beef-kidney': 3.4972076493484514,
#  'australian': 4.218603314493725,
#  'pasta-salad': 3.504848484848485,
#  'omelets-and-frittatas': 3.950609630088861,
#  'desserts-fruit': 3.5015064365927144,
#  'deep-fry': 4.015004966800857,
#  'meatloaf': 3.5529649448509337,
#  'main-dish-beef': 3.509886225560588,
#  'green-yellow-beans': 3.8723883654240066,
#  'squid': 3.550452710810516,
#  'st-patricks-day': 3.770565045992116,
#  'steaks': 3.881258866179793,
#  'saltwater-fish': 4.834339025120897,
#  'chinese-new-year': 3.518324321372003,
#  'new-years': 4.311485857149861,
#  'filipino': 3.57527759634226,
#  'shrimp-main-dish': 3.500250152871199,
#  'sweet-sauces': 3.6261628514685897,
#  'refrigerator': 4.702350782137551,
#  'guatemalan': 3.5009334504722163,
#  'finnish': 3.5581181311244654,
#  'korean': 3.5821382007822686,
#  'trout': 3.562904109589041,
#  'austrian': 3.582217343578485,
#  'rosh-hashanah': 3.5342638896521406,
#  'non-alcoholic': 3.5278395229059365,
#  'stews-poultry': 3.4909595904585555,
#  'moose': 3.5271693696706237,
#  'cambodian': 3.5120280563318538,
#  'libyan': 3.474786231089673,
#  'beijing': 3.512504788485744,
#  'iranian-persian': 3.621968461120174,
#  'bok-choys': 3.544763882815916,
#  'chicken-stews': 3.5082112247719106,
#  'college': 3.511268689533861,
#  'independence-day': 4.10637159533074,
#  'chicken-thighs-legs': 4.145581465931509,
#  'chicken-crock-pot': 3.5050559965206047,
#  'picnic': 5.04966607814539,
#  'cheesecake': 4.446999439147504,
#  'gumbo': 3.6034682080924854,
#  'nepalese': 3.5187945024010596,
#  'soy-tofu': 3.9271849645681423,
#  'crock-pot-main-dish': 3.515550840359596,
#  'middle-eastern-main-dish': 3.4853982300884954,
#  'crab': 3.950655712609073,
#  'gluten-free': 4.7919290090851465,
#  'lasagna': 4.090599201065246,
#  'deer': 3.6036775570513875,
#  'laotian': 3.493464938445686,
#  'baked-beans': 3.4936835106382977,
#  'egyptian': 3.5796514209591472,
#  'beef-sausage': 3.676327981898502,
#  'wild-game': 3.695546295795227,
#  'octopus': 3.4925356629437134,
#  'main-dish-pasta': 3.5126578787711655,
#  'roast-beef-main-dish': 3.524678950307091,
#  'salad-dressings': 3.719867615095831,
#  'pakistani': 3.557893002306932,
#  'black-bean-soup': 3.503279763857002,
#  'creole': 3.805019815059445,
#  'cuban': 3.5884474561451447,
#  'christmas': 5.920157018179046,
#  'broil': 4.065104166666667,
#  'venezuelan': 3.496940364931019,
#  'halloween-cakes': 3.4989791977045743,
#  'beef-ribs': 3.617224880382775,
#  'pears': 3.756370779358675,
#  'chick-peas-garbanzos': 3.819497053872054,
#  'halloween': 3.7389933746527038,
#  'prepared-potatoes': 3.5132198880328143,
#  'whole-turkey': 3.6933993399339933,
#  'peanut-butter': 3.58467937982821,
#  'argentine': 3.5665815193247448,
#  'hand-formed-cookies': 4.259456205478077}

# %% [markdown]
# 4. Решите задачу 3, распараллелив вычисления с помощью модуля `multiprocessing`. Для обработки каждого файла создайте свой собственный процесс. Определите, за какое время задача решается для всех файлов.

# %%
# %%file create_df_file.py
import pandas as pd
def create_df(file):
    df = pd.read_csv(file, sep=";")
    return df
# Out:
# Writing create_df_file.py

# %%
# %%time
#более точное, но менее эффективное решение
import create_df_file
if __name__ == "__main__":
    files = ['./output/id_tag_nsteps_' + str(i) + '.csv' for i in range(1, 9)]
    pool = mp.Pool(processes=len(files))
    df_lst = pool.map(create_df_file.create_df, files)

tags_dict = mean_step_df(pd.concat(df_lst))
tags_dict
# Out:
# Wall time: 10.9 s
# {'mexican': 5.302344316442439,
#  'healthy-2': 6.384162244806188,
#  'orange-roughy': 3.513425052701653,
#  'chicken-thighs-legs': 4.145581465931509,
#  'freezer': 4.033042234819468,
#  'whitefish': 3.514734127201888,
#  'pork-sausage': 4.256068444090729,
#  'brunch': 6.871661962657403,
#  'ham-and-bean-soup': 3.508423254789694,
#  'colombian': 3.5359842260926717,
#  'savory-pies': 4.298328243879716,
#  'refrigerator': 4.702350782137551,
#  'australian': 4.218603314493725,
#  'served-cold': 4.911621189054144,
#  'spaghetti': 4.0825152293208475,
#  'passover': 3.658676110051757,
#  'quick-breads': 5.059023265562775,
#  'californian': 3.74143203627544,
#  'namibian': 3.5042895887529752,
#  'candy': 4.229612689762553,
#  'independence-day': 4.10637159533074,
#  'baking': 3.6306821245618766,
#  'pennsylvania-dutch': 3.5471966710468683,
#  'weeknight': 7.413649806241077,
#  '60-minutes-or-less': 9.413654300607185,
#  'time-to-make': 9.27850778138217,
#  'course': 9.274686706181202,
#  'cuisine': 9.1700252580716,
#  'preparation': 9.293416400880012,
#  'occasion': 9.136277173913044,
#  'north-american': 8.187233786366852,
#  'desserts': 9.023456628905357,
#  'dinner-party': 8.233824137497079,
#  'holiday-event': 8.308282439870316,
#  'cookies-and-brownies': 6.727248893986564,
#  'gelatin': 3.7341488168367074,
#  'high-in-something': 5.465606147416669,
#  'barbecue': 4.596669048044293,
#  'main-ingredient': 9.315210297605468,
#  'main-dish': 9.442468712421503,
#  'poultry': 7.673893983554892,
#  'easy': 7.253311258278146,
#  'chicken': 7.325226860254084,
#  'one-dish-meal': 7.003855449418805,
#  'comfort-food': 7.501074976803132,
#  'meat': 8.918907625325192,
#  'chicken-breasts': 5.757057608446178,
#  'taste-mood': 8.455551143132695,
#  'peppers': 4.517914691943128,
#  'grapes': 3.5634223090277777,
#  'veal': 3.6804319513783375,
#  'kid-friendly': 7.095590014296712,
#  'breakfast-casseroles': 3.506533222129552,
#  'peruvian': 3.5665068569517224,
#  'filipino': 3.57527759634226,
#  'for-large-groups': 7.293004554911994,
#  'pasta-salad': 3.504848484848485,
#  'rosh-hashana': 3.6900091857135138,
#  'dips-summer': 3.484745194456862,
#  'chutneys': 3.5558799675587998,
#  'mardi-gras-carnival': 3.6024259489900903,
#  'small-appliance': 5.241089441829186,
#  'desserts-easy': 3.5050172725777267,
#  'high-protein': 5.007946914610402,
#  'beginner-cook': 6.326035834266517,
#  'bacon': 4.10665269251884,
#  'pork-loins': 4.010719834282755,
#  'beef-barley-soup': 3.498673006745549,
#  'crab': 3.950655712609073,
#  'collard-greens': 3.5319676193622995,
#  'long-grain-rice': 3.9543551305246836,
#  'oatmeal': 3.500110460620789,
#  'deer': 3.6036775570513875,
#  'Throw the ultimate fiesta with this sopaipillas recipe from Food.com.': 3.5116482077581974,
#  'camping': 3.934283942963422,
#  'quebec': 3.5783718768793396,
#  'chicken-crock-pot': 3.5050559965206047,
#  'microwave': 4.0819245134656965,
#  'shrimp-main-dish': 3.500250152871199,
#  'medium-grain-rice': 3.550438716006322,
#  'low-protein': 6.2924007830574835,
#  'german': 4.057022013860579,
#  'european': 8.016243513066952,
#  'sandwiches': 4.794260578131546,
#  'beef-sauces': 3.5037515745659675,
#  'rolls-biscuits': 4.37720346579026,
#  'steam': 3.6812774622226985,
#  'memorial-day': 3.526248754014841,
#  'salads': 5.062135863099777,
#  'biscotti': 3.7415754686314875,
#  'wedding': 3.921485635680652,
#  'mashed-potatoes': 3.52792349726776,
#  'pressure-canning': 3.538096551724138,
#  'eggs-dairy': 7.623189911287474,
#  'tropical-fruit': 4.590361445783133,
#  'easter': 4.4522793071298885,
#  'cinco-de-mayo': 3.5550013702384216,
#  'granola-and-porridge': 3.7370038545681843,
#  'sole-and-flounder': 3.580126803672934,
#  'irish': 3.7723708239338274,
#  'cambodian': 3.5120280563318538,
#  'pasta': 6.5836000512098325,
#  'dairy-free': 3.5595883286801335,
#  'potatoes': 5.894798342834886,
#  'scottish': 3.7987558485750745,
#  'bean-soup': 3.506754893851668,
#  'bar-cookies': 4.8392488262910796,
#  'valentines-day': 4.472800344481126,
#  'cooking-mixes': 3.609224057338735,
#  'icelandic': 3.502124183006536,
#  'pork-chops': 4.036843453753523,
#  'lamb-sheep': 4.130016786204791,
#  'kiwifruit': 3.5339135164536306,
#  'coconut': 4.106659284240197,
#  'georgian': 3.4969924397108327,
#  'less_thansql:name_topics_of_recipegreater_than': 3.5148095133230566,
#  'crock-pot-main-dish': 3.515550840359596,
#  'greek': 4.349770081205362,
#  'dutch': 3.5777420428080293,
#  'seafood': 6.374263556570879,
#  'thai': 3.899144946945503,
#  'spinach': 4.175668854114083,
#  'christmas': 5.920157018179046,
#  'freshwater-fish': 3.8349246764269043,
#  'cake-fillings-and-frostings': 3.9406652527029125,
#  'mussels': 3.5937723103959582,
#  'asian': 6.445874984183222,
#  'jewish-ashkenazi': 3.794318242844101,
#  'casseroles': 5.341411232256737,
#  'romantic': 5.15583577207781,
#  'unprocessed-freezer': 3.5198803854247425,
#  'fruit': 7.310792710151398,
#  'cabbage': 3.5122165004930426,
#  'grains': 5.206610190710679,
#  'equipment': 8.574089581965914,
#  '15-minutes-or-less': 4.986565505243319,
#  '30-minutes-or-less': 7.610132158590308,
#  'lime': 3.6746153439433193,
#  'czech': 3.5725535547111624,
#  'iranian-persian': 3.621968461120174,
#  'eggs': 5.909033055066821,
#  'salad-dressings': 3.719867615095831,
#  'appetizers': 6.231012410189419,
#  'side-dishes': 6.676337302292518,
#  'vegetables': 8.089443895926909,
#  'american': 7.575099698868723,
#  'fall': 5.555992292870906,
#  'finger-food': 5.2388437512758745,
#  'picnic': 5.04966607814539,
#  'spring': 4.533591324303649,
#  'summer': 5.304315317239906,
#  'vegetarian': 7.214044577077311,
#  'winter': 5.496159515866243,
#  'stove-top': 7.2552827380952385,
#  'dietary': 8.846635478817191,
#  'copycat': 4.257255936675461,
#  'seasonal': 6.8062785416614675,
#  'brown-bag': 4.355984628362545,
#  'inexpensive': 6.93097739322388,
#  'toddler-friendly': 4.594735231098867,
#  'novelty': 4.800665178766794,
#  'to-go': 6.433847655720368,
#  'presentation': 7.177265370270461,
#  'served-hot': 6.44635292560233,
#  '3-steps-or-less': 4.7288194719733605,
#  'oven': 8.348988512757956,
#  'brazilian': 3.5924736363149723,
#  'pork': 6.4437282286681645,
#  'canning': 3.9452296819787986,
#  'chicken-livers': 3.544458514562572,
#  'wild-game': 3.695546295795227,
#  'puddings-and-mousses': 4.324805667617829,
#  'beans-side-dishes': 3.5152363696260913,
#  'ontario': 3.737262156448203,
#  'savory': 6.042196451026967,
#  'low-sodium': 7.3863798933541425,
#  'bass': 3.5415725384318697,
#  'meatballs': 3.541812330059375,
#  'prepared-potatoes': 3.5132198880328143,
#  'oaxacan': 3.5224962918200298,
#  'saudi-arabian': 3.531842893598136,
#  'zucchini': 3.58697079094191,
#  'roast-beef': 4.015181449516481,
#  'caribbean': 3.9957735849056606,
#  'flat-shapes': 3.83120286677007,
#  'healthy': 7.080629201214727,
#  'italian': 5.8739571150097465,
#  'low-cholesterol': 6.621511553915241,
#  'low-saturated-fat': 6.505154015290581,
#  'low-calorie': 6.726496822286123,
#  'low-carb': 7.247922207446808,
#  'low-in-something': 8.057098661645034,
#  'green-yellow-beans': 3.8723883654240066,
#  'tomatoes': 4.863886342804766,
#  'for-1-or-2': 5.473579840874465,
#  'nepalese': 3.5187945024010596,
#  'pasta-rice-and-grains': 7.771835927957539,
#  'white-rice': 3.8467779684818226,
#  'lasagne': 3.5145545102379634,
#  'reynolds-wrap': 3.565602449158102,
#  'norwegian': 3.5663843361566383,
#  'egyptian': 3.5796514209591472,
#  'simply-potatoes': 3.6358264485418834,
#  'clear-soups': 3.7017780172413794,
#  'soups-stews': 5.9352367453005295,
#  'beans': 5.485727808927401,
#  '4-hours-or-less': 10.065263998344003,
#  'beef': 6.937072852565011,
#  'ground-beef': 5.532396415715708,
#  'burgers': 3.5708975620421994,
#  'high-calcium': 4.515901675005439,
#  'nuts': 5.503219139972975,
#  'snacks-kid-friendly': 3.5009977827050998,
#  'manicotti': 3.614364640883978,
#  'heirloom-historical-recipes': 3.5178403496155335,
#  'pheasant': 3.520208171852508,
#  'fudge': 3.7261221016804935,
#  'micro-melanesia': 3.5141301957334505,
#  'cajun': 3.910293213040804,
#  'breakfast-eggs': 3.510853437379788,
#  'cranberry-sauce': 3.495701058201058,
#  'ham': 4.030267694179679,
#  'laotian': 3.493464938445686,
#  'wings': 3.6984937995635745,
#  'muffins': 4.305949143647727,
#  'ethiopian': 3.509815849140076,
#  'whole-turkey': 3.6933993399339933,
#  'cuban': 3.5884474561451447,
#  'austrian': 3.582217343578485,
#  'guatemalan': 3.5009334504722163,
#  'pickeral': 3.4951028942445252,
#  'stir-fry': 4.167118746232671,
#  'roast-beef-main-dish': 3.524678950307091,
#  'high-in-something-diabetic-friendly': 3.5027038958172385,
#  'belgian': 3.573172048817367,
#  'duck': 3.5997391020763128,
#  'middle-eastern-main-dish': 3.4853982300884954,
#  'curries': 4.056318540535001,
#  'pies-and-tarts': 5.233969866853539,
#  'snacks-sweet': 3.4965144163738775,
#  'heirloom-historical': 5.063579485371871,
#  'honduran': 3.5143279011265447,
#  'halloween-cocktails': 3.514611821790913,
#  'baked-beans': 3.4936835106382977,
#  'trout': 3.562904109589041,
#  'chicken-stews': 3.5082112247719106,
#  'lunch': 6.678860028860029,
#  'midwestern': 4.399375384469787,
#  'egg-free': 4.786737262390417,
#  'free-of-something': 5.713046100241222,
#  'number-of-servings': 7.848588714912623,
#  'potluck': 5.740600062724327,
#  'dips': 4.025779588944012,
#  'spreads': 3.84343757695149,
#  'cheese': 6.524772252655791,
#  'sweet-sauces': 3.6261628514685897,
#  'somalian': 3.520300016305234,
#  'shellfish': 5.401717519490284,
#  'squash': 4.694080622020642,
#  'libyan': 3.474786231089673,
#  'chilean': 3.5288842429577465,
#  'pitted-fruit': 4.122290471597543,
#  'chowders': 3.8468745120491334,
#  'southern-united-states': 5.231357927786499,
#  'no-shell-fish': 3.562639516524201,
#  'steaks': 3.881258866179793,
#  'turkey-burgers': 3.4884499314128945,
#  'kwanzaa': 3.6018448997103936,
#  'irish-st-patricks-day': 3.518823333147973,
#  'infant-baby-friendly': 3.6132161914515173,
#  'celebrity': 3.7695260436103855,
#  'costa-rican': 3.513296565281494,
#  'marinara-sauce': 3.522765969132751,
#  'macaroni-and-cheese': 3.5318565632196512,
#  'bisques-cream-soups': 4.132540995938017,
#  'cantonese': 3.5635441362959694,
#  'scandinavian': 3.953488372093023,
#  'french': 4.472535520726527,
#  'hanukkah': 3.7728091554519443,
#  'chinese-new-year': 3.518324321372003,
#  'pumpkin-bread': 3.509180673434293,
#  '1-day-or-more': 4.459439233685891,
#  'amish-mennonite': 3.560696788241698,
#  'mixer': 4.301563056870831,
#  'blueberries': 3.9650378038260516,
#  'spanish': 3.8625397321661197,
#  'pressure-cooker': 3.667061547574175,
#  'birthday': 3.6248698416178002,
#  'low-fat': 5.944445829697045,
#  'african': 4.372096337466154,
#  'turkey': 4.414412664497645,
#  'gluten-free': 4.7919290090851465,
#  'pork-loin': 3.487238597068994,
#  'main-dish-beef': 3.509886225560588,
#  'water-bath': 3.7291033434650456,
#  'lactose': 4.548202468252549,
#  'british-columbian': 3.718204621871164,
#  'main-dish-pork': 3.513633340722678,
#  'ragu-recipe-contest': 3.5131040583877033,
#  'pizza': 4.149197643713183,
#  'mahi-mahi': 3.5369613771313397,
#  'creole': 3.805019815059445,
#  'swedish': 3.6309587004989914,
#  'mango': 3.681424395429179,
#  'pork-crock-pot': 3.510396975425331,
#  'oamc-freezer-make-ahead': 5.101522613292369,
#  'crock-pot-slow-cooker': 4.700854008985308,
#  'bear': 3.494859606455892,
#  'stews': 4.120702672773946,
#  'condiments-etc': 4.7830466911886536,
#  'tuna': 3.8548345860817097,
#  'brewing': 3.534414513468939,
#  'veggie-burgers': 3.512272148041443,
#  'served-hot-new-years': 3.5059235775070916,
#  'pork-ribs': 3.711184495452577,
#  'rolled-cookies': 3.933474801061008,
#  'indonesian': 3.582323121005069,
#  'lettuces': 3.7256257199706777,
#  'lentils': 3.9327888466940646,
#  'breads': 7.1460181064907164,
#  'tarts': 3.7580992358196106,
#  'south-american': 3.941121832911915,
#  'black-bean-soup': 3.503279763857002,
#  'food-processor-blender': 4.479378963481303,
#  'polish': 3.6785428556189665,
#  'punch': 3.5956371512557372,
#  'puerto-rican': 3.540382513661202,
#  'non-alcoholic': 3.5278395229059365,
#  'superbowl': 4.055649492739208,
#  'pakistani': 3.557893002306932,
#  'jewish-sephardi': 3.5652531229454305,
#  'mongolian': 3.5210330876240095,
#  'chick-peas-garbanzos': 3.819497053872054,
#  'beef-sausage': 3.676327981898502,
#  'pasta-rice-and-grains-elbow-macaroni': 3.491643223564455,
#  'vegan': 5.190527141736215,
#  '5-ingredients-or-less': 5.345920719916704,
#  'hunan': 3.5117907354506244,
#  'chinese': 4.309035268148297,
#  'salmon': 4.205071502285125,
#  'fish': 5.300345857569565,
#  'saltwater-fish': 4.834339025120897,
#  'baja': 3.53721200066302,
#  'herb-and-spice-mixes': 3.552204547880858,
#  'black-beans': 3.93185306456564,
#  'pot-roast': 3.488254387412664,
#  'salsas': 3.605928790075721,
#  'breakfast': 6.098151629072682,
#  'kosher': 4.825991189427313,
#  'mushroom-soup': 3.4856729538752576,
#  'greens': 4.658566221142163,
#  'a1-sauce': 3.5280419809773695,
#  'whole-chicken': 4.0393326645900425,
#  'cakes': 6.733708189158016,
#  'shakes': 3.525634933206611,
#  'ramadan': 3.6026196087028004,
#  'halloween-cupcakes': 3.5033479692645444,
#  'moose': 3.5271693696706237,
#  'finnish': 3.5581181311244654,
#  'dips-lunch-snacks': 3.507624309392265,
#  'jellies': 3.5721814724259713,
#  'cherries': 3.707792207792208,
#  'turkish': 3.620761690502973,
#  'palestinian': 3.5308247479477717,
#  'pasta-shells': 3.697942342728539,
#  'south-west-pacific': 4.414301359861276,
#  'quiche': 3.5354525921436837,
#  'breakfast-potatoes': 3.501639891044527,
#  'lemon': 4.108630574864275,
#  'strawberries': 4.110803597904517,
#  'english': 4.146556529671109,
#  'for-large-groups-holiday-event': 3.5172128890112915,
#  'duck-breasts': 3.5412215387935686,
#  'pies': 4.679968336747998,
#  'vietnamese': 3.6583629893238436,
#  'drop-cookies': 4.393322360686574,
#  'ecuadorean': 3.516626558739882,
#  'polynesian': 3.553561718325177,
#  'snacks': 4.974996093139553,
#  'szechuan': 3.553976808753879,
#  'citrus': 4.549448073890516,
#  'gifts': 5.5754301720688275,
#  'broccoli': 4.107340720221607,
#  'bread-machine': 3.793686699912601,
#  'new-zealand': 3.6738208797032326,
#  'technique': 5.330086325618891,
#  'no-cook': 3.9530264947051794,
#  'tempeh': 3.527434613244296,
#  'carrots': 4.3147672093687515,
#  'cauliflower': 3.85839378238342,
#  'mothers-day': 3.558894362342638,
#  'northeastern-united-states': 4.325447229359577,
#  'frozen-desserts': 4.038928837093975,
#  'brown-rice': 3.719026197406721,
#  'tilapia': 3.6113482842475007,
#  'lobster': 3.59012222775289,
#  'spaghetti-sauce': 3.508873435326843,
#  'rosh-hashanah': 3.5342638896521406,
#  'pacific-northwest': 3.7700684505289357,
#  'scallops': 3.766795657314845,
#  'octopus': 3.4925356629437134,
#  'roast-beef-comfort-food': 3.498625316177279,
#  'cupcakes': 3.9464164357781377,
#  'halloween': 3.7389933746527038,
#  'whole-duck': 3.537125152152263,
#  'labor-day': 3.5164488258750555,
#  'pasta-elbow-macaroni': 3.4888071985076263,
#  'indian': 4.467002398081535,
#  'side-dishes-beans': 3.501832111925383,
#  'stocks': 3.6284188379996762,
#  'bananas': 4.000644649409898,
#  'sweet': 6.063357532390843,
#  'lamb-sheep-main-dish': 3.496599015650058,
#  'hidden-valley-ranch': 3.56636587366694,
#  'sauces': 4.232691901036159,
#  'stews-poultry': 3.4909595904585555,
#  'apples': 4.85682676038006,
#  'main-dish-pasta': 3.5126578787711655,
#  'moroccan': 3.8259548383716666,
#  'danish': 3.5856840045654654,
#  'korean': 3.5821382007822686,
#  'pork-loins-roast': 3.51767830465335,
#  'meatloaf': 3.5529649448509337,
#  'grilling': 4.793819410912603,
#  'chard': 3.586361401016338,
#  'cobblers-and-crisps': 3.910389202762084,
#  'canadian': 4.764779480763216,
#  'berries': 4.987671744634926,
#  'garnishes': 3.6137860853730386,
#  'raspberries': 3.9046359017781542,
#  'peaches': 3.778925836567712,
#  'penne': 3.9567099567099566,
#  'oranges': 3.8910941736150186,
#  'beef-crock-pot': 3.4955118673935788,
#  'gumbo': 3.6034682080924854,
#  'cheesecake': 4.446999439147504,
#  'ravioli-tortellini': 3.7443362324878913,
#  'quail': 3.502773547966065,
#  'super-bowl': 3.582380485680061,
#  'chicken-stew': 3.480013380163907,
#  'middle-eastern': 4.191139303236038,
#  'spicy': 5.450922706606044,
#  'asparagus': 4.047421217955213,
#  'japanese': 3.788570832681579,
#  'venezuelan': 3.496940364931019,
#  'april-fools-day': 3.5103864194773284,
#  'goose': 3.5103463538784996,
#  'beef-kidney': 3.4972076493484514,
#  'beverages': 3.899079152278421,
#  'nigerian': 3.485750232481812,
#  'rabbit': 3.5241744307844973,
#  'argentine': 3.5665815193247448,
#  'pineapple': 3.9677019864269085,
#  'soul': 3.5588170985022414,
#  'broil': 4.065104166666667,
#  'smoothies': 3.4916926794884704,
#  'mushrooms': 4.6644879149816605,
#  'pears': 3.756370779358675,
#  'omelets-and-frittatas': 3.950609630088861,
#  'onions': 5.003155255878285,
#  'south-african': 3.6286164034087824,
#  'cocktails': 3.61964958970947,
#  'high-fiber': 3.518181818181818,
#  'college': 3.511268689533861,
#  'st-patricks-day': 3.770565045992116,
#  'main-dish-chicken': 3.5083209754490032,
#  'bok-choys': 3.544763882815916,
#  'lasagna': 4.090599201065246,
#  'soy-tofu': 3.9271849645681423,
#  'oysters': 3.568528198074278,
#  'rice': 5.126250103314323,
#  'halloween-cakes': 3.4989791977045743,
#  'beef-organ-meats': 3.5562640866362485,
#  'portuguese': 3.6449111470113085,
#  'pumpkin': 3.559947586809347,
#  'yeast': 5.179112222274636,
#  'roast': 4.020509341404864,
#  'iraqi': 3.5319321813552897,
#  'avocado': 3.531110989071338,
#  'sudanese': 3.496088407462115,
#  'diabetic': 4.895048701298701,
#  'crusts-pastry-dough-2': 3.6874797450577943,
#  'simply-potatoes2': 3.508810081409613,
#  'pancakes-and-waffles': 4.1733998419597,
#  'russian': 3.7004585918532507,
#  'steak': 3.92369043943604,
#  'new-years': 4.311485857149861,
#  'perch': 3.494737416153133,
#  'desserts-fruit': 3.5015064365927144,
#  'welsh': 3.5899640796778054,
#  'chocolate-chip-cookies': 3.519182286528554,
#  'stuffings-dressings': 3.717682339081075,
#  'beef-ribs': 3.617224880382775,
#  'dehydrator': 3.5021339461588967,
#  'central-american': 4.059544571229259,
#  'coffee-cakes': 4.042268842268842,
#  'halibut': 3.6225172830023045,
#  'bread-pudding': 3.5062297601405126,
#  'tex-mex': 3.951607133731923,
#  'fathers-day': 3.5008259911894273,
#  'lebanese': 3.6328620185275478,
#  'scones': 3.8034052453468696,
#  'catfish': 3.5580889154921915,
#  'elk': 3.5071385591597832,
#  'eggplant': 3.5645143548564513,
#  'thanksgiving': 4.958787389569039,
#  'jams-and-preserves': 3.850592261121348,
#  'fillings-and-frostings-chocolate': 3.5121640343585483,
#  'plums': 3.5635477155691904,
#  'malaysian': 3.57388691614313,
#  'crawfish': 3.52754767331962,
#  'marinades-and-rubs': 3.5826751592356687,
#  'deep-fry': 4.015004966800857,
#  'chocolate': 6.202489956932431,
#  'hawaiian': 3.625,
#  'chili': 3.9434637885818034,
#  'squid': 3.550452710810516,
#  'cod': 3.6570873995794466,
#  'turkey-breasts': 3.6294220093610536,
#  'beijing': 3.512504788485744,
#  'native-american': 3.5655307994757535,
#  'savory-sauces': 3.812120306742356,
#  'main-dish-seafood': 3.5055491771909684,
#  'swiss': 3.6533907427341226,
#  'southwestern-united-states': 4.4924616164876205,
#  'yams-sweet-potatoes': 4.005262620069487,
#  'ice-cream': 3.5219947855993787,
#  'melons': 3.6164650184113625,
#  'sourdough': 3.5868755903761738,
#  'hungarian': 3.664425862163196,
#  'nut-free': 3.580711763107851,
#  'short-grain-rice': 3.689175985235045,
#  'shrimp': 4.860226515656229,
#  'congolese': 3.4968992681155373,
#  'peanut-butter': 3.58467937982821,
#  'brownies': 3.9802875816993466,
#  'papaya': 3.545848890841204,
#  'sugar-cookies': 3.537796619501184,
#  'very-low-carbs': 5.320270764727406,
#  'leftovers': 3.628175895765472,
#  'elbow-macaroni': 4.0664339254543584,
#  'hand-formed-cookies': 4.259456205478077,
#  'clams': 3.635291572000433,
#  'from-scratch': 4.745889101338432,
#  'pot-pie': 3.5088093674764718,
#  'corn': 4.076911822083496,
#  'artichoke': 3.4960065645514224,
#  'smoker': 3.581018647369886,
#  'beef-liver': 3.550352718991279,
#  'eggs-breakfast': 3.4854300315320215,
#  'angolan': 3.4931362780914426}

# %%
# %%time
#менее точное, но более эффективное решение
import mean_step_file
if __name__ == "__main__":
    files = ['./output/id_tag_nsteps_' + str(i) + '.csv' for i in range(1, 9)]
    pool = mp.Pool(processes=len(files))
    dict_lst = pool.map(mean_step_file.mean_step, files)

answer_dict = dict_lst[0]

for item in dict_lst[1:]:
    answer_dict = {**answer_dict, **item}
answer_dict
# Out:
# Wall time: 5.38 s
# {'mexican': 5.237799834574028,
#  'healthy-2': 6.4895543175487465,
#  'orange-roughy': 3.4735955056179777,
#  'chicken-thighs-legs': 4.114686040477426,
#  'freezer': 4.025737265415549,
#  'whitefish': 3.563073394495413,
#  'pork-sausage': 4.4013464526152255,
#  'brunch': 6.8151685393258425,
#  'ham-and-bean-soup': 3.4655847789591494,
#  'colombian': 3.513454146073586,
#  'savory-pies': 4.320610687022901,
#  'refrigerator': 4.708088567555355,
#  'australian': 4.2594224180127265,
#  'served-cold': 4.973520249221184,
#  'spaghetti': 4.14344262295082,
#  'passover': 3.6161504424778763,
#  'quick-breads': 5.207394815129621,
#  'californian': 3.7439712673165726,
#  'namibian': 3.5486425339366514,
#  'candy': 4.237891737891738,
#  'independence-day': 4.0960614793467816,
#  'baking': 3.629139072847682,
#  'pennsylvania-dutch': 3.603139013452915,
#  'weeknight': 7.309997416688194,
#  '60-minutes-or-less': 9.454514207149405,
#  'time-to-make': 9.286383210000418,
#  'course': 9.288817065287654,
#  'cuisine': 9.219791472723887,
#  'preparation': 9.298885304805847,
#  'occasion': 9.175841096312265,
#  'north-american': 8.239652767012867,
#  'desserts': 8.965273311897105,
#  'dinner-party': 8.324255163589838,
#  'holiday-event': 8.294397865853659,
#  'cookies-and-brownies': 6.656696576935859,
#  'gelatin': 3.7915538711423933,
#  'high-in-something': 5.540128682695564,
#  'barbecue': 4.590762124711317,
#  'main-ingredient': 9.298883880661085,
#  'main-dish': 9.433079677708147,
#  'poultry': 7.643744030563515,
#  'easy': 7.2543006204173714,
#  'chicken': 7.301055408970976,
#  'one-dish-meal': 7.096792668957617,
#  'comfort-food': 7.5202548930359585,
#  'meat': 8.85081459539518,
#  'chicken-breasts': 5.6642023346303505,
#  'taste-mood': 8.480417381360777,
#  'peppers': 4.54725168756027,
#  'grapes': 3.5593784683684793,
#  'veal': 3.673446327683616,
#  'kid-friendly': 7.0165607985480944,
#  'breakfast-casseroles': 3.5120274914089347,
#  'peruvian': 3.5034207525655643,
#  'filipino': 3.5682191780821917,
#  'for-large-groups': 7.197558268590455,
#  'pasta-salad': 3.5352422907488985,
#  'rosh-hashana': 3.725108225108225,
#  'dips-summer': 3.512359550561798,
#  'chutneys': 3.633104902477596,
#  'mardi-gras-carnival': 3.6115342763873777,
#  'small-appliance': 5.082379017362394,
#  'desserts-easy': 3.5139821029082774,
#  'high-protein': 5.057244374259771,
#  'beginner-cook': 6.36034353995519,
#  'bacon': 4.159079283887468,
#  'pork-loins': 4.057040082219938,
#  'beef-barley-soup': 3.568844807467911,
#  'crab': 3.966403162055336,
#  'collard-greens': 3.551605504587156,
#  'long-grain-rice': 3.938053097345133,
#  'oatmeal': 3.5013550135501355,
#  'deer': 3.634810464495462,
#  'Throw the ultimate fiesta with this sopaipillas recipe from Food.com.': 3.584937712344281,
#  'camping': 3.8891129032258065,
#  'quebec': 3.5635005336179297,
#  'chicken-crock-pot': 3.485903814262023,
#  'microwave': 4.0755842864246645,
#  'shrimp-main-dish': 3.4414923685698136,
#  'medium-grain-rice': 3.617863199547767,
#  'low-protein': 6.354240631163708,
#  'german': 4.059663437021928,
#  'european': 8.10473933649289,
#  'sandwiches': 4.8466386554621845,
#  'beef-sauces': 3.4551951621770205,
#  'rolls-biscuits': 4.37857847976308,
#  'steam': 3.6648351648351647,
#  'memorial-day': 3.54017094017094,
#  'salads': 4.968381897086175,
#  'biscotti': 3.6653888280394304,
#  'wedding': 3.8845327604726103,
#  'mashed-potatoes': 3.533931575995513,
#  'pressure-canning': 3.532875929102344,
#  'eggs-dairy': 7.627987082884823,
#  'tropical-fruit': 4.60343347639485,
#  'easter': 4.395049504950495,
#  'cinco-de-mayo': 3.524627720504009,
#  'granola-and-porridge': 3.7921378567582122,
#  'sole-and-flounder': 3.6131868131868132,
#  'irish': 3.707547169811321,
#  'cambodian': 3.4969829950630826,
#  'pasta': 6.6962445995347295,
#  'dairy-free': 3.5901639344262297,
#  'potatoes': 5.866318147871546,
#  'scottish': 3.814134668892599,
#  'bean-soup': 3.4631401238041644,
#  'bar-cookies': 4.771387143547607,
#  'valentines-day': 4.3463414634146345,
#  'cooking-mixes': 3.566367001586462,
#  'icelandic': 3.4782129067843353,
#  'pork-chops': 4.205430327868853,
#  'lamb-sheep': 4.077557755775578,
#  'kiwifruit': 3.5399305555555554,
#  'coconut': 4.130180658873539,
#  'georgian': 3.528521536670547,
#  'less_thansql:name_topics_of_recipegreater_than': 3.5374791782343142,
#  'crock-pot-main-dish': 3.494985250737463,
#  'greek': 4.230350963914978,
#  'dutch': 3.564667033571822,
#  'seafood': 6.302182600676299,
#  'thai': 3.8753799392097266,
#  'spinach': 4.207664422578975,
#  'christmas': 6.098618572524942,
#  'freshwater-fish': 3.886460554371002,
#  'cake-fillings-and-frostings': 3.858515750133476,
#  'mussels': 3.621505376344086,
#  'asian': 6.521067867481506,
#  'jewish-ashkenazi': 3.6309983452840595,
#  'casseroles': 5.275459098497496,
#  'romantic': 5.230836236933798,
#  'unprocessed-freezer': 3.52759009009009,
#  'fruit': 7.316220085907139,
#  'cabbage': 3.488202247191011,
#  'grains': 5.140230867892262,
#  'equipment': 8.552553579571363,
#  '15-minutes-or-less': 4.990266060999351,
#  '30-minutes-or-less': 7.572010678656738,
#  'lime': 3.7423674343867166,
#  'czech': 3.6023359288097887,
#  'iranian-persian': 3.634478996181124,
#  'eggs': 5.820464054773678,
#  'salad-dressings': 3.7032032032032034,
#  'appetizers': 6.174202127659575,
#  'side-dishes': 6.574123989218329,
#  'vegetables': 8.002820874471086,
#  'american': 7.562254800743341,
#  'fall': 5.641376613218616,
#  'finger-food': 5.050270045700041,
#  'picnic': 5.119526627218935,
#  'spring': 4.4879518072289155,
#  'summer': 5.29027729027729,
#  'vegetarian': 7.180928626247122,
#  'winter': 5.5965732087227416,
#  'stove-top': 7.269182389937107,
#  'dietary': 8.82522661950033,
#  'copycat': 4.35051045211473,
#  'seasonal': 6.859437751004016,
#  'brown-bag': 4.339562443026436,
#  'inexpensive': 6.86946059755364,
#  'toddler-friendly': 4.6414516834280715,
#  'novelty': 4.962754439151148,
#  'to-go': 6.505824979680304,
#  'presentation': 7.058217537134643,
#  'served-hot': 6.335895721925134,
#  '3-steps-or-less': 4.7471649896182715,
#  'oven': 8.346790890269151,
#  'brazilian': 3.573932092004381,
#  'pork': 6.577677709874558,
#  'canning': 4.035694970254191,
#  'chicken-livers': 3.4940217391304347,
#  'wild-game': 3.7110621904237755,
#  'puddings-and-mousses': 4.290354822588705,
#  'beans-side-dishes': 3.5173745173745172,
#  'ontario': 3.6650273224043715,
#  'savory': 6.059992771955186,
#  'low-sodium': 7.368033992482432,
#  'bass': 3.5542372881355933,
#  'meatballs': 3.5618938961779807,
#  'prepared-potatoes': 3.5169263836646962,
#  'oaxacan': 3.547984099943214,
#  'saudi-arabian': 3.5418774592467677,
#  'zucchini': 3.5992152466367715,
#  'roast-beef': 4.104992279979413,
#  'caribbean': 3.95625,
#  'flat-shapes': 3.9096809085992428,
#  'healthy': 7.173119944932026,
#  'italian': 5.96,
#  'low-cholesterol': 6.6712353801169595,
#  'low-saturated-fat': 6.499697641604516,
#  'low-calorie': 6.859977949283352,
#  'low-carb': 7.332153690596562,
#  'low-in-something': 8.128599221789884,
#  'green-yellow-beans': 3.86022070415134,
#  'tomatoes': 4.8749471905365445,
#  'for-1-or-2': 5.456439869445142,
#  'nepalese': 3.5466439135381114,
#  'pasta-rice-and-grains': 7.87575962187711,
#  'white-rice': 3.8295151838039425,
#  'lasagne': 3.4803591470258137,
#  'reynolds-wrap': 3.570945945945946,
#  'norwegian': 3.5381679389312977,
#  'egyptian': 3.502227171492205,
#  'simply-potatoes': 3.5828635851183765,
#  'clear-soups': 3.656862745098039,
#  'soups-stews': 5.941438356164384,
#  'beans': 5.470544646165246,
#  '4-hours-or-less': 10.186025408348458,
#  'beef': 6.86752261453166,
#  'ground-beef': 5.4678935003915425,
#  'burgers': 3.5917901938426455,
#  'high-calcium': 4.535118525021949,
#  'nuts': 5.369336569579288,
#  'snacks-kid-friendly': 3.484536082474227,
#  'manicotti': 3.618458075407991,
#  'heirloom-historical-recipes': 3.524024872809497,
#  'pheasant': 3.5651447661469935,
#  'fudge': 3.7238928376161837,
#  'micro-melanesia': 3.539622641509434,
#  'cajun': 3.9042443064182195,
#  'breakfast-eggs': 3.5270798436627584,
#  'cranberry-sauce': 3.479977753058954,
#  'ham': 4.106874059207225,
#  'laotian': 3.5428875865743206,
#  'wings': 3.730538922155689,
#  'muffins': 4.223018147086915,
#  'ethiopian': 3.431638418079096,
#  'whole-turkey': 3.7538546255506606,
#  'cuban': 3.661588683351469,
#  'austrian': 3.6001144164759724,
#  'guatemalan': 3.4806022003474233,
#  'pickeral': 3.501890869800108,
#  'stir-fry': 4.143790849673203,
#  'roast-beef-main-dish': 3.510662177328844,
#  'high-in-something-diabetic-friendly': 3.4789053591790196,
#  'belgian': 3.5497012493210214,
#  'duck': 3.6489659027389605,
#  'middle-eastern-main-dish': 3.4865967365967365,
#  'curries': 3.9835456475583864,
#  'pies-and-tarts': 5.330310880829016,
#  'snacks-sweet': 3.4581473214285716,
#  'heirloom-historical': 4.908056440600819,
#  'honduran': 3.4932049830124576,
#  'halloween-cocktails': 3.497752808988764,
#  'baked-beans': 3.441860465116279,
#  'trout': 3.550647820965842,
#  'chicken-stews': 3.4788888888888887,
#  'lunch': 6.592916060164969,
#  'midwestern': 4.28494623655914,
#  'egg-free': 4.890712742980561,
#  'free-of-something': 5.7429445766746,
#  'number-of-servings': 7.824145242512589,
#  'potluck': 5.893699401619148,
#  'dips': 4.046804680468047,
#  'spreads': 3.8209939148073024,
#  'cheese': 6.468123316372344,
#  'sweet-sauces': 3.5864955357142856,
#  'somalian': 3.5274605764002174,
#  'shellfish': 5.405773857257418,
#  'squash': 4.681513409961686,
#  'libyan': 3.4244090159428255,
#  'chilean': 3.51269584008644,
#  'pitted-fruit': 4.049415515409139,
#  'chowders': 3.825947677522691,
#  'southern-united-states': 5.120553359683795,
#  'no-shell-fish': 3.538034425319267,
#  'steaks': 3.8217768147345614,
#  'turkey-burgers': 3.5101258894362344,
#  'kwanzaa': 3.637735849056604,
#  'irish-st-patricks-day': 3.518316019682887,
#  'infant-baby-friendly': 3.6450905101481075,
#  'celebrity': 3.851891891891892,
#  'costa-rican': 3.4723564143853998,
#  'marinara-sauce': 3.50542888165038,
#  'macaroni-and-cheese': 3.510092744135297,
#  'bisques-cream-soups': 4.158572844400396,
#  'cantonese': 3.578212290502793,
#  'scandinavian': 3.9701173959445035,
#  'french': 4.57536304456685,
#  'hanukkah': 3.75498426023085,
#  'chinese-new-year': 3.561123348017621,
#  'pumpkin-bread': 3.5250836120401337,
#  '1-day-or-more': 4.402915148360229,
#  'amish-mennonite': 3.6031233171782446,
#  'mixer': 4.157274590163935,
#  'blueberries': 3.9138804457953396,
#  'spanish': 3.950310559006211,
#  'pressure-cooker': 3.667687595712098,
#  'birthday': 3.638919514884234,
#  'low-fat': 5.9959473150962515,
#  'african': 4.320420851267336,
#  'turkey': 4.492596248766041,
#  'gluten-free': 4.893816631130064,
#  'pork-loin': 3.492836676217765,
#  'main-dish-beef': 3.5284646348476136,
#  'water-bath': 3.7827476038338657,
#  'lactose': 4.4590312358533275,
#  'british-columbian': 3.6699399890889253,
#  'main-dish-pork': 3.5284186831738884,
#  'ragu-recipe-contest': 3.3956916099773244,
#  'pizza': 4.118759852863899,
#  'mahi-mahi': 3.4846153846153847,
#  'creole': 3.833245660178853,
#  'swedish': 3.5949781659388647,
#  'mango': 3.6236914600550962,
#  'pork-crock-pot': 3.5497412305922946,
#  'oamc-freezer-make-ahead': 4.96900269541779,
#  'crock-pot-slow-cooker': 4.820099255583126,
#  'bear': 3.5066518847006654,
#  'stews': 4.180610236220472,
#  'condiments-etc': 4.820530023482053,
#  'tuna': 3.8459633481921744,
#  'brewing': 3.5068719076415613,
#  'veggie-burgers': 3.4617456896551726,
#  'served-hot-new-years': 3.5801393728222997,
#  'pork-ribs': 3.771191135734072,
#  'rolled-cookies': 3.9147043432757718,
#  'indonesian': 3.6407322654462244,
#  'lettuces': 3.723876556578235,
#  'lentils': 3.856537850714664,
#  'breads': 7.184658212186823,
#  'tarts': 3.652733118971061,
#  'south-american': 3.916941694169417,
#  'black-bean-soup': 3.4441951766685364,
#  'food-processor-blender': 4.445040214477212,
#  'polish': 3.700868621064061,
#  'punch': 3.5231259968102075,
#  'puerto-rican': 3.542682926829268,
#  'non-alcoholic': 3.4498644986449865,
#  'superbowl': 4.031023784901758,
#  'pakistani': 3.5833333333333335,
#  'jewish-sephardi': 3.569406641262929,
#  'mongolian': 3.5607734806629834,
#  'chick-peas-garbanzos': 3.813762971054069,
#  'beef-sausage': 3.5918708240534523,
#  'pasta-rice-and-grains-elbow-macaroni': 3.519438444924406,
#  'vegan': 5.173387096774194,
#  '5-ingredients-or-less': 5.455691367456073,
#  'hunan': 3.543538546866334,
#  'chinese': 4.420556107249255,
#  'salmon': 4.15122199592668,
#  'fish': 5.227009113504557,
#  'saltwater-fish': 4.746869409660107,
#  'baja': 3.545299145299145,
#  'herb-and-spice-mixes': 3.5053042992741483,
#  'black-beans': 3.8861154446177846,
#  'pot-roast': 3.4593582887700536,
#  'salsas': 3.6554798112218143,
#  'breakfast': 5.976819059884095,
#  'kosher': 4.873366381252817,
#  'mushroom-soup': 3.4337281443880427,
#  'greens': 4.628405538186691,
#  'a1-sauce': 3.581564245810056,
#  'whole-chicken': 4.010209869540556,
#  'cakes': 6.690554943035648,
#  'shakes': 3.4613259668508287,
#  'ramadan': 3.601063829787234,
#  'halloween-cupcakes': 3.460972850678733,
#  'moose': 3.4885666480758504,
#  'finnish': 3.573789173789174,
#  'dips-lunch-snacks': 3.5755716675962073,
#  'jellies': 3.625692137320044,
#  'cherries': 3.6344426835710513,
#  'turkish': 3.6070489216202,
#  'palestinian': 3.529053680132817,
#  'pasta-shells': 3.7030497592295344,
#  'south-west-pacific': 4.56093023255814,
#  'quiche': 3.5668824163969797,
#  'breakfast-potatoes': 3.5452586206896552,
#  'lemon': 4.171753750646663,
#  'strawberries': 4.096273291925466,
#  'english': 4.141358641358641,
#  'for-large-groups-holiday-event': 3.471590909090909,
#  'duck-breasts': 3.5442752397067117,
#  'pies': 4.78496583143508,
#  'vietnamese': 3.7528641571194763,
#  'drop-cookies': 4.391325536062378,
#  'ecuadorean': 3.4735973597359737,
#  'polynesian': 3.558790593505039,
#  'snacks': 4.916036609629924,
#  'szechuan': 3.5016483516483516,
#  'citrus': 4.609389671361503,
#  'gifts': 5.573962112051592,
#  'broccoli': 4.06456382454411,
#  'bread-machine': 3.82931829830856,
#  'new-zealand': 3.691891891891892,
#  'technique': 5.316421895861148,
#  'no-cook': 3.9789690721649484,
#  'tempeh': 3.5231032515687395,
#  'carrots': 4.304,
#  'cauliflower': 3.9544290834613416,
#  'mothers-day': 3.5753268902785673,
#  'northeastern-united-states': 4.306945118989801,
#  'frozen-desserts': 4.05286783042394,
#  'brown-rice': 3.7472979927946475,
#  'tilapia': 3.6703848298940325,
#  'lobster': 3.6449638286032275,
#  'spaghetti-sauce': 3.500846023688663,
#  'rosh-hashanah': 3.5077899596076167,
#  'pacific-northwest': 3.6988727858293076,
#  'scallops': 3.9407965554359525,
#  'octopus': 3.5179372197309418,
#  'roast-beef-comfort-food': 3.4920110192837464,
#  'cupcakes': 3.853080568720379,
#  'halloween': 3.727422907488987,
#  'whole-duck': 3.6089983931440814,
#  'labor-day': 3.5662921348314605,
#  'pasta-elbow-macaroni': 3.4892205638474296,
#  'indian': 4.537320810677212,
#  'side-dishes-beans': 3.5200433369447452,
#  'stocks': 3.5841252096143097,
#  'bananas': 4.032961460446248,
#  'sweet': 6.201262272089761,
#  'lamb-sheep-main-dish': 3.5121687398593835,
#  'hidden-valley-ranch': 3.5690639269406392,
#  'sauces': 4.238135593220339,
#  'stews-poultry': 3.426025917926566,
#  'apples': 4.979664014146773,
#  'main-dish-pasta': 3.511013215859031,
#  'moroccan': 3.863782051282051,
#  'danish': 3.588996763754045,
#  'korean': 3.552417164584465,
#  'pork-loins-roast': 3.486501687289089,
#  'meatloaf': 3.570189701897019,
#  'grilling': 4.748961698200277,
#  'chard': 3.6177455357142856,
#  'cobblers-and-crisps': 3.8859132297803964,
#  'canadian': 4.705476300046019,
#  'berries': 4.996524761077324,
#  'garnishes': 3.6655808903365905,
#  'raspberries': 4.061892583120205,
#  'peaches': 3.778178075141534,
#  'penne': 4.042918454935623,
#  'oranges': 3.9471776281719317,
#  'beef-crock-pot': 3.458216489063376,
#  'gumbo': 3.5903337169159952,
#  'cheesecake': 4.450026164311879,
#  'ravioli-tortellini': 3.765082754938601,
#  'quail': 3.4965259219668625,
#  'super-bowl': 3.5440713536201467,
#  'chicken-stew': 3.540909090909091,
#  'middle-eastern': 4.242439266236985,
#  'spicy': 5.409213051823417,
#  'asparagus': 4.193850964043773,
#  'japanese': 3.8184764991896274,
#  'venezuelan': 3.589944134078212,
#  'april-fools-day': 3.5871453387376953,
#  'goose': 3.5377611140867704,
#  'beef-kidney': 3.54251012145749,
#  'beverages': 3.9028551532033426,
#  'nigerian': 3.469713656387665,
#  'rabbit': 3.578860898138007,
#  'argentine': 3.5140080045740425,
#  'pineapple': 4.056112224448897,
#  'soul': 3.6345093715545755,
#  'broil': 4.109109109109109,
#  'smoothies': 3.503560528992879,
#  'mushrooms': 4.607613469985359,
#  'pears': 3.8058727569331157,
#  'omelets-and-frittatas': 3.8830624016780284,
#  'onions': 4.964,
#  'south-african': 3.557606263982103,
#  'cocktails': 3.6032461677186656,
#  'high-fiber': 3.4368421052631577,
#  'college': 3.5197992191857224,
#  'st-patricks-day': 3.7793141592920354,
#  'main-dish-chicken': 3.498367791077258,
#  'bok-choys': 3.6034985422740524,
#  'lasagna': 4.21296813862493,
#  'soy-tofu': 3.9399896533885155,
#  'oysters': 3.5870422535211266,
#  'rice': 5.240485829959514,
#  'halloween-cakes': 3.4717083786724703,
#  'beef-organ-meats': 3.578080636002271,
#  'portuguese': 3.66058981233244,
#  'pumpkin': 3.536281179138322,
#  'yeast': 5.147951807228916,
#  'roast': 3.98919197117859,
#  'iraqi': 3.5128351397604107,
#  'avocado': 3.4669421487603307,
#  'sudanese': 3.5265462506841816,
#  'diabetic': 4.776310359059018,
#  'crusts-pastry-dough-2': 3.62624584717608,
#  'simply-potatoes2': 3.5040562466197946,
#  'pancakes-and-waffles': 4.067094227923039,
#  'russian': 3.669908157752566,
#  'steak': 3.8791910590739755,
#  'new-years': 4.303015323776569,
#  'perch': 3.462049861495845,
#  'desserts-fruit': 3.4835972850678734,
#  'welsh': 3.5843870258383728,
#  'chocolate-chip-cookies': 3.467495760316563,
#  'stuffings-dressings': 3.6765840220385675,
#  'beef-ribs': 3.669491525423729,
#  'dehydrator': 3.5150987224157957,
#  'central-american': 4.014668689934243,
#  'coffee-cakes': 3.9671189979123174,
#  'halibut': 3.638333333333333,
#  'bread-pudding': 3.511924570160843,
#  'tex-mex': 3.9888324873096446,
#  'fathers-day': 3.4823788546255505,
#  'lebanese': 3.531720430107527,
#  'scones': 3.9128745837957823,
#  'catfish': 3.5327050997782705,
#  'elk': 3.486633933442444,
#  'eggplant': 3.5235055136390017,
#  'thanksgiving': 5.022810218978102,
#  'jams-and-preserves': 3.833607006020799,
#  'fillings-and-frostings-chocolate': 3.4779735682819384,
#  'plums': 3.542652724270776,
#  'malaysian': 3.5846867749419955,
#  'crawfish': 3.551123595505618,
#  'marinades-and-rubs': 3.6338102808691044,
#  'deep-fry': 4.027469624933968,
#  'chocolate': 6.194068106920542,
#  'hawaiian': 3.659327925840093,
#  'chili': 3.9233520694941237,
#  'squid': 3.546286329386437,
#  'cod': 3.640346133044889,
#  'turkey-breasts': 3.651024811218986,
#  'beijing': 3.5145945945945947,
#  'native-american': 3.6902944383860414,
#  'savory-sauces': 3.709507883420927,
#  'main-dish-seafood': 3.5008431703204046,
#  'swiss': 3.5773710482529117,
#  'southwestern-united-states': 4.49480642115203,
#  'yams-sweet-potatoes': 4.040296924708377,
#  'ice-cream': 3.5970404097894138,
#  'melons': 3.628143392188336,
#  'sourdough': 3.705199115044248,
#  'hungarian': 3.6984478935698446,
#  'nut-free': 3.588527302813017,
#  'short-grain-rice': 3.6850948509485093,
#  'shrimp': 4.728260869565218,
#  'congolese': 3.4893267651888342,
#  'peanut-butter': 3.596244131455399,
#  'brownies': 3.9277044854881265,
#  'papaya': 3.569119286510591,
#  'sugar-cookies': 3.5451928612550376,
#  'very-low-carbs': 5.291635548917102,
#  'leftovers': 3.654377880184332,
#  'elbow-macaroni': 4.067085953878407,
#  'hand-formed-cookies': 4.294753086419753,
#  'clams': 3.6152137701277067,
#  'from-scratch': 4.566145092460882,
#  'pot-pie': 3.5102493074792243,
#  'corn': 4.011268985791279,
#  'artichoke': 3.483170466883822,
#  'smoker': 3.514552443712246,
#  'beef-liver': 3.520954598370198,
#  'eggs-breakfast': 3.4316969050160084,
#  'angolan': 3.458844133099825}

# %% [markdown]
# 5. Решите задачу 3, распараллелив вычисления с помощью модуля `multiprocessing`. Создайте фиксированное количество процессов (равное половине количества ядер на компьютере). При помощи очереди `multiprocessing.queue` передайте названия файлов для обработки процессам и при помощи другой очереди заберите от них ответы.

# %%
# %%file queue_file.py

import pandas as pd
from multiprocessing import Process, Queue, current_process, freeze_support

def worker(input_, output):
    for args in iter(input_.get, 'STOP'):
        result = mean_step(args)
        output.put(result)


def mean_step(file):
    tags_dict = {}
    df = pd.read_csv(file, sep=";")
    df_tags = df.groupby('tags').mean()["n_steps"]
    df = df.dropna()
    df_tags = df_tags.dropna()
    for tag in df["tags"]:
        if tag not in tags_dict:
            tags_dict[tag] = df_tags[tag]
    return tags_dict
# Out:
# Overwriting queue_file.py

# %%
# %%time
import queue_file
from multiprocessing import Process, Queue, current_process, freeze_support

def mean_count():
    NUMBER_OF_PROCESSES = 2
    files = ['./output/id_tag_nsteps_' + str(i) + '.csv' for i in range(1, 9)]

    task_queue = Queue()
    done_queue = Queue()

    for task in files:
        task_queue.put(task)

    for i in range(NUMBER_OF_PROCESSES):
        Process(target=queue_file.worker, args=(task_queue, done_queue)).start()

    answer_dict = done_queue.get()
    for i in range(1, len(files)):
        answer_dict = {**answer_dict, **done_queue.get()}

    for i in range(NUMBER_OF_PROCESSES):
        task_queue.put('STOP')
        
    return answer_dict

freeze_support()

answer_dict = mean_count()
answer_dict
# Out:
# Wall time: 5.93 s
# {'brewing': 3.5512489233419466,
#  'savory-pies': 4.33929331630481,
#  'italian': 5.731601731601732,
#  'romantic': 5.115137148662377,
#  'clear-soups': 3.668134507606085,
#  'french': 4.5325329202168865,
#  'long-grain-rice': 3.965784114052953,
#  'pacific-northwest': 3.7850895460224905,
#  'muffins': 4.350530552506403,
#  'chutneys': 3.4971994829814737,
#  'beef-ribs': 3.6419437340153453,
#  'palestinian': 3.4731273804485823,
#  'gifts': 5.62914511712808,
#  'stews': 4.179968701095461,
#  'cherries': 3.680960548885077,
#  'chicken-breasts': 5.773991031390135,
#  'mushroom-soup': 3.4742630884293884,
#  'kiwifruit': 3.508720930232558,
#  'freshwater-fish': 3.848278622898319,
#  'prepared-potatoes': 3.5017421602787455,
#  'high-fiber': 3.5095785440613025,
#  'ontario': 3.7576,
#  'roast-beef-main-dish': 3.486706689536878,
#  'greens': 4.6670182841068915,
#  'holiday-event': 8.438943894389439,
#  'creole': 3.7266881028938905,
#  'bananas': 4.009750390015601,
#  'garnishes': 3.5953684210526315,
#  'tomatoes': 4.867651782846129,
#  'raspberries': 3.8148604269293926,
#  'szechuan': 3.6180382377389857,
#  'spinach': 4.154872624342904,
#  'goose': 3.5195993031358883,
#  'cambodian': 3.5201511335012596,
#  'cranberry-sauce': 3.5990295544772826,
#  'main-dish-chicken': 3.5044359949302915,
#  'dips-summer': 3.4819700967458225,
#  '3-steps-or-less': 4.745524915336236,
#  'brazilian': 3.5899782135076252,
#  'meatballs': 3.497900923593619,
#  'pork': 6.510309278350515,
#  'swedish': 3.665302782324059,
#  'low-carb': 7.2772499340195305,
#  'native-american': 3.569856054191363,
#  'grilling': 4.820353063343718,
#  'beef': 6.7626329787234045,
#  'mashed-potatoes': 3.4728102947281028,
#  'broccoli': 4.119968737788199,
#  'winter': 5.365693865396069,
#  'strawberries': 4.119402985074627,
#  'beans-side-dishes': 3.5336810082572794,
#  'pasta-salad': 3.533187772925764,
#  'no-shell-fish': 3.5733830845771144,
#  '30-minutes-or-less': 7.654828326180257,
#  'time-to-make': 9.22148718274919,
#  'course': 9.236118863897554,
#  'main-ingredient': 9.24531172890278,
#  'cuisine': 9.051948972360028,
#  'preparation': 9.256409455703713,
#  'occasion': 9.11777138495861,
#  'for-1-or-2': 5.513751169317119,
#  'main-dish': 9.403556175368255,
#  'eggs-dairy': 7.54582584545009,
#  'poultry': 7.75255054720831,
#  'vegetables': 8.01195652173913,
#  'easy': 7.202175883952856,
#  'european': 7.917497733454216,
#  'dinner-party': 8.273657647553623,
#  'spring': 4.6341798215511325,
#  'summer': 5.175,
#  'english': 4.161226114649682,
#  'chicken': 7.400609756097561,
#  'seasonal': 6.778275257932646,
#  'meat': 8.897540554683411,
#  'onions': 4.9649298597194385,
#  'taste-mood': 8.430263449191942,
#  'number-of-servings': 7.84641738449491,
#  'presentation': 7.197382970880944,
#  'served-hot': 6.4060228452751815,
#  'kosher': 4.7654576856649395,
#  'fudge': 3.6897126197417744,
#  'blueberries': 3.9902200488997557,
#  'heirloom-historical-recipes': 3.4896907216494846,
#  'australian': 4.175578308684111,
#  'small-appliance': 5.186320754716981,
#  'beef-sausage': 3.7648068669527897,
#  'low-protein': 6.261682242990654,
#  'diabetic': 4.912418300653595,
#  'malaysian': 3.6034410407049937,
#  'tropical-fruit': 4.646189224704337,
#  'mexican': 5.3113867684478375,
#  'rolls-biscuits': 4.389494163424125,
#  'pork-ribs': 3.7482688391038694,
#  'pies': 4.795232936078007,
#  'macaroni-and-cheese': 3.503899480069324,
#  'north-american': 8.131687242798353,
#  'appetizers': 6.205025927403271,
#  'dietary': 8.848247544869624,
#  'inexpensive': 6.819188191881919,
#  'peppers': 4.41383055756698,
#  'polish': 3.7654220779220777,
#  'sweet': 6.099339570720969,
#  'independence-day': 4.176255038475632,
#  'dips': 4.010427528675704,
#  'snacks': 4.938198757763975,
#  'zucchini': 3.628677994198094,
#  'chicken-stew': 3.4487825356842987,
#  'beef-barley-soup': 3.463620981387479,
#  'cheese': 6.427027027027027,
#  'beef-sauces': 3.518612521150592,
#  'pies-and-tarts': 5.314827352742045,
#  'halloween-cocktails': 3.551575312904618,
#  'ragu-recipe-contest': 3.5228161668839637,
#  'lobster': 3.573248407643312,
#  'soups-stews': 5.951471347444502,
#  'marinara-sauce': 3.4959626009349765,
#  'mixer': 4.277132559070885,
#  'high-calcium': 4.642857142857143,
#  'stocks': 3.6934632561916363,
#  'freezer': 4.031176929072486,
#  'brown-bag': 4.302037845705968,
#  'cantonese': 3.5522833973538197,
#  'south-west-pacific': 4.341252699784017,
#  'duck': 3.5961132234896493,
#  'pork-loin': 3.4827011254689455,
#  'filipino': 3.5804997951659154,
#  'jams-and-preserves': 3.8492929292929294,
#  'jellies': 3.6569468267581473,
#  'sole-and-flounder': 3.609009774755631,
#  'low-in-something': 8.01311254308407,
#  'quiche': 3.5935455734845183,
#  'egg-free': 4.880662609871535,
#  'portuguese': 3.646095717884131,
#  'mushrooms': 4.647591452372329,
#  'low-calorie': 6.588125627420049,
#  'sudanese': 3.5047777316161195,
#  'whole-chicken': 4.131023496614895,
#  'green-yellow-beans': 3.8880126182965298,
#  'lactose': 4.588539868829824,
#  'spreads': 3.877798861480076,
#  'whole-duck': 3.5670897552130554,
#  'korean': 3.595639654463184,
#  'whitefish': 3.4971702220287333,
#  'stove-top': 7.151883830455259,
#  'saltwater-fish': 4.791212421539478,
#  'birthday': 3.5962036238136323,
#  'cobblers-and-crisps': 3.995573440643863,
#  'quail': 3.497691984892992,
#  'hungarian': 3.691748610517315,
#  '15-minutes-or-less': 5.005327716515922,
#  '5-ingredients-or-less': 5.354076008123005,
#  'salads': 4.967427484545887,
#  'fruit': 7.245738636363637,
#  'no-cook': 4.004757373929591,
#  'salad-dressings': 3.6570327552986512,
#  'pears': 3.775072224515064,
#  'lettuces': 3.765154556403051,
#  'technique': 5.377100025846472,
#  'brunch': 6.738601196616464,
#  'pork-loins': 3.9700837654567214,
#  'pot-pie': 3.4711206896551725,
#  'nepalese': 3.5023861171366595,
#  'thai': 3.9587264150943398,
#  'spanish': 3.8984689766317486,
#  'microwave': 4.133281673769857,
#  'ramadan': 3.5492487479131887,
#  'american': 7.521683673469388,
#  'casseroles': 5.32776025236593,
#  'avocado': 3.5224766751484307,
#  'tuna': 3.9033293221018854,
#  'crock-pot-main-dish': 3.516616314199396,
#  'vietnamese': 3.6224968044311887,
#  'dutch': 3.5955153083225526,
#  'veal': 3.6707869798104658,
#  'pork-sausage': 4.308777429467084,
#  'cajun': 3.8917023763147642,
#  'to-go': 6.434367034834325,
#  'plums': 3.582798459563543,
#  'belgian': 3.577259475218659,
#  'seafood': 6.288394718554552,
#  'southwestern-united-states': 4.5346002151308715,
#  'spicy': 5.48408956982911,
#  'one-dish-meal': 6.917097281509773,
#  'low-cholesterol': 6.581165158371041,
#  'tilapia': 3.5251921434671223,
#  'beef-kidney': 3.5138097325734328,
#  'equipment': 8.506023044692737,
#  'breakfast-eggs': 3.477990217874611,
#  'chinese': 4.345773038842346,
#  'ice-cream': 3.5286652078774616,
#  'brown-rice': 3.742939009414654,
#  'melons': 3.6077551020408163,
#  'japanese': 3.910189287152638,
#  'pennsylvania-dutch': 3.546814878153057,
#  'irish-st-patricks-day': 3.535205183585313,
#  'sourdough': 3.6189856957087128,
#  'lamb-sheep-main-dish': 3.5316455696202533,
#  'south-african': 3.698224852071006,
#  'norwegian': 3.554803216250529,
#  'quick-breads': 5.052434456928839,
#  'angolan': 3.5172558922558923,
#  'bok-choys': 3.5466278101582014,
#  'rabbit': 3.503445305770887,
#  'eggs-breakfast': 3.48596564725597,
#  'venezuelan': 3.5341695501730106,
#  'chicken-stews': 3.5494880546075085,
#  'midwestern': 4.3845307917888565,
#  'super-bowl': 3.5643823657791356,
#  'pasta-rice-and-grains-elbow-macaroni': 3.5103359173126614,
#  'jewish-ashkenazi': 3.741711011051985,
#  'for-large-groups': 7.2086085659492865,
#  'pressure-canning': 3.539906103286385,
#  'coffee-cakes': 4.065767973856209,
#  'bean-soup': 3.4956672443674175,
#  'pumpkin-bread': 3.4902459711620017,
#  'sugar-cookies': 3.5459119496855345,
#  'high-in-something-diabetic-friendly': 3.496551724137931,
#  'very-low-carbs': 5.355047941342358,
#  'beginner-cook': 6.220732410611303,
#  'potluck': 5.784030010718114,
#  'picnic': 5.031351671103224,
#  'turkey': 4.504665920119447,
#  'low-sodium': 7.355273189326557,
#  'low-saturated-fat': 6.460018668326073,
#  'middle-eastern-main-dish': 3.4606694560669458,
#  'christmas': 6.092171344165436,
#  'argentine': 3.505786540934419,
#  'burgers': 3.575821398483572,
#  'gumbo': 3.5994077834179357,
#  'bacon': 4.100191938579655,
#  'main-dish-seafood': 3.556687898089172,
#  'pheasant': 3.5426356589147288,
#  'costa-rican': 3.5120034919249234,
#  '60-minutes-or-less': 9.40210377441881,
#  'side-dishes': 6.719249956992947,
#  'vegan': 5.170091941590049,
#  'vegetarian': 7.196941278314817,
#  'healthy-2': 6.304551772063934,
#  'carrots': 4.364038319823139,
#  'savory': 6.083265747499325,
#  'valentines-day': 4.51335528723015,
#  'citrus': 4.593091537132988,
#  'superbowl': 4.120955882352941,
#  '4-hours-or-less': 9.896208042158323,
#  'desserts': 8.939271765150561,
#  'cuban': 3.6154485049833887,
#  'puddings-and-mousses': 4.3631156930126,
#  'fathers-day': 3.5183566433566433,
#  'water-bath': 3.6545693047660692,
#  'roast-beef': 4.066693451185215,
#  'pakistani': 3.548085106382979,
#  'oven': 8.400377714825307,
#  'iraqi': 3.5042769857433806,
#  'cabbage': 3.5533249686323716,
#  'whole-turkey': 3.760310330747244,
#  'catfish': 3.5780467445742903,
#  'mahi-mahi': 3.5647869134739563,
#  'czech': 3.5538793103448274,
#  'pasta-shells': 3.7661193432118543,
#  'short-grain-rice': 3.6587268993839834,
#  'perch': 3.4924874791318863,
#  'roast': 4.009885330170028,
#  'lamb-sheep': 4.158680282796544,
#  'californian': 3.7225998300764656,
#  'fish': 5.283559577677225,
#  'high-protein': 5.100768049155146,
#  'high-in-something': 5.568374967808396,
#  'chicken-livers': 3.537037037037037,
#  'chilean': 3.529940119760479,
#  'duck-breasts': 3.5964403973509933,
#  'pancakes-and-waffles': 4.097113884555382,
#  'british-columbian': 3.7438258685642527,
#  'corn': 4.147688838782413,
#  'side-dishes-beans': 3.523578669017188,
#  'hidden-valley-ranch': 3.6169654569304766,
#  'squash': 4.754020467836257,
#  'cakes': 6.518065591995553,
#  'icelandic': 3.5598958333333335,
#  'april-fools-day': 3.5157894736842104,
#  'iranian-persian': 3.6624095359727544,
#  'rolled-cookies': 3.96044499381953,
#  'healthy': 7.058138012308498,
#  'southern-united-states': 5.267135862913097,
#  'tempeh': 3.5021186440677967,
#  'halibut': 3.61048839071257,
#  'laotian': 3.556756756756757,
#  'bear': 3.493344783168742,
#  'oatmeal': 3.5286783042394014,
#  'danish': 3.5403996524761077,
#  'wedding': 3.887444128403088,
#  'breakfast-potatoes': 3.503225806451613,
#  'chocolate': 6.137325905292479,
#  'lime': 3.7981535879143937,
#  'jewish-sephardi': 3.5392736486486487,
#  'for-large-groups-holiday-event': 3.5567375886524824,
#  'heirloom-historical': 5.267272137528382,
#  'somalian': 3.530811729706757,
#  'marinades-and-rubs': 3.638540031397174,
#  'oaxacan': 3.5080988917306053,
#  'passover': 3.6884088076443704,
#  'herb-and-spice-mixes': 3.563311688311688,
#  'ravioli-tortellini': 3.708855640921957,
#  'apples': 4.858795508676421,
#  'candy': 4.251588785046729,
#  'beef-organ-meats': 3.62410394265233,
#  'spaghetti': 3.992782678428228,
#  'cookies-and-brownies': 6.795860284605434,
#  'spaghetti-sauce': 3.4993446920052427,
#  'pumpkin': 3.547680412371134,
#  'cheesecake': 4.474771553436631,
#  'bar-cookies': 4.82946013585985,
#  'beans': 5.393593314763232,
#  'chick-peas-garbanzos': 3.7873042044517726,
#  'clams': 3.7240495514737293,
#  'chard': 3.5907190635451505,
#  'bread-machine': 3.843011613936724,
#  'shakes': 3.523149980213692,
#  'yeast': 5.271095152603231,
#  'central-american': 4.140289175459164,
#  'nigerian': 3.4823989569752283,
#  'lebanese': 3.5359477124183005,
#  'free-of-something': 5.773287850957754,
#  'grains': 5.160426081342802,
#  'libyan': 3.565622353937341,
#  'celebrity': 3.78978471929084,
#  'ecuadorean': 3.5191578947368423,
#  'halloween-cupcakes': 3.45625,
#  'frozen-desserts': 3.95796986518636,
#  'lunch': 6.650571323258386,
#  'shellfish': 5.392998477929985,
#  'asian': 6.3709559717830215,
#  'st-patricks-day': 3.837314662273476,
#  'crawfish': 3.543918918918919,
#  'steam': 3.6235644406635474,
#  'cupcakes': 3.968888888888889,
#  'pickeral': 3.455432937181664,
#  'penne': 3.9370012599748003,
#  'orange-roughy': 3.489831241886629,
#  'bass': 3.4931335830212236,
#  'condiments-etc': 4.853208691258211,
#  'russian': 3.7120239623448867,
#  'mardi-gras-carnival': 3.6579957356076758,
#  'ground-beef': 5.35806548513067,
#  'leftovers': 3.5869384359401,
#  'wings': 3.653923541247485,
#  'mussels': 3.6228941684665226,
#  'kwanzaa': 3.658557046979866,
#  'hand-formed-cookies': 4.383582662063675,
#  'octopus': 3.477095937770095,
#  'gluten-free': 4.758263772954925,
#  'breakfast': 6.0701712654614655,
#  'potatoes': 5.817349137931035,
#  'kid-friendly': 7.109097127222983,
#  'chicken-crock-pot': 3.5219573400250943,
#  'amish-mennonite': 3.6052051168945742,
#  'pasta-elbow-macaroni': 3.5021331058020477,
#  'main-dish-pasta': 3.4762320104666378,
#  'scottish': 3.834747474747475,
#  'breads': 7.2093735280263775,
#  'eggs': 5.924852071005917,
#  'sandwiches': 4.834868421052631,
#  'cocktails': 3.602532536053465,
#  'novelty': 4.749573524394405,
#  'squid': 3.5730720068172133,
#  'pineapple': 3.90852228303362,
#  'white-rice': 3.8212749315604224,
#  'savory-sauces': 3.8828795225662067,
#  'shrimp': 4.826160053799597,
#  'comfort-food': 7.4275910610592994,
#  'artichoke': 3.438671209540034,
#  'bread-pudding': 3.4902376910016977,
#  'mothers-day': 3.565325591041062,
#  'asparagus': 4.002430133657351,
#  'trout': 3.630672268907563,
#  'granola-and-porridge': 3.806827309236948,
#  'chicken-thighs-legs': 4.139389193422083,
#  'sweet-sauces': 3.671089666264576,
#  'peaches': 3.7576749897666804,
#  'breakfast-casseroles': 3.529201961658493,
#  'flat-shapes': 3.8365503080082135,
#  'middle-eastern': 4.146858743497399,
#  'food-processor-blender': 4.428523149712741,
#  'micro-melanesia': 3.5370946246112838,
#  'rice': 5.223228728566807,
#  'berries': 4.996229971724788,
#  'sauces': 4.297253106605624,
#  'steaks': 3.895673271330368,
#  'low-fat': 5.839772727272727,
#  'steak': 3.7975,
#  'halloween-cakes': 3.503176620076239,
#  'beef-crock-pot': 3.5668402777777777,
#  'eggplant': 3.6054968287526425,
#  'from-scratch': 4.795674005407493,
#  'pizza': 4.033073929961089,
#  'punch': 3.568714632174616,
#  'desserts-fruit': 3.414686825053996,
#  'refrigerator': 4.60390047074647,
#  'namibian': 3.5328237410071943,
#  'cod': 3.7130289065772937,
#  'oysters': 3.5805340223944877,
#  'tarts': 3.816482582837723,
#  'mongolian': 3.5577264653641207,
#  'copycat': 4.172143974960877,
#  'hanukkah': 3.7643776824034334,
#  'wild-game': 3.637895602137279,
#  'cake-fillings-and-frostings': 3.868544600938967,
#  'indian': 4.438524590163935,
#  'finger-food': 5.2919937205651495,
#  'caribbean': 4.037227722772277,
#  'medium-grain-rice': 3.587406793703397,
#  'colombian': 3.518534482758621,
#  'camping': 3.963317384370016,
#  'finnish': 3.5836909871244633,
#  'roast-beef-comfort-food': 3.4971503726435773,
#  'lentils': 3.8964948453608246,
#  'pasta': 6.562282012954658,
#  'salmon': 4.180257510729613,
#  'congolese': 3.479379157427938,
#  'scallops': 3.7938835358190195,
#  'turkish': 3.639898562975486,
#  'chinese-new-year': 3.5126416739319963,
#  'weeknight': 7.406713505074161,
#  'memorial-day': 3.548680225010818,
#  'moose': 3.517211328976035,
#  'new-zealand': 3.661388550548112,
#  'college': 3.495315161839864,
#  '1-day-or-more': 4.487038491751767,
#  'reynolds-wrap': 3.5328435609334488,
#  'omelets-and-frittatas': 4.013888888888889,
#  'lemon': 4.1330724070450096,
#  'brownies': 3.9431864965006174,
#  'halloween': 3.769042769857434,
#  'crock-pot-slow-cooker': 4.681569343065694,
#  'soy-tofu': 3.90398406374502,
#  'pork-chops': 3.943644590703414,
#  'baking': 3.5517241379310347,
#  'veggie-burgers': 3.4660151043980454,
#  'broil': 4.124515128006206,
#  'turkey-burgers': 3.4853751589656636,
#  'swiss': 3.655385885266199,
#  'served-hot-new-years': 3.483814523184602,
#  'peruvian': 3.614452617914323,
#  'pot-roast': 3.519538188277087,
#  'elk': 3.551752921535893,
#  'infant-baby-friendly': 3.6247379454926625,
#  'papaya': 3.6005004170141786,
#  'unprocessed-freezer': 3.5764411027568923,
#  'drop-cookies': 4.385190459238163,
#  'easter': 4.660886319845857,
#  'honduran': 3.5175,
#  'curries': 4.090234375,
#  'manicotti': 3.699831365935919,
#  'shrimp-main-dish': 3.5023554603854388,
#  'dips-lunch-snacks': 3.5167926112510495,
#  'german': 3.967704280155642,
#  'egyptian': 3.646606914212548,
#  'nuts': 5.455728340209458,
#  'thanksgiving': 5.072100313479623,
#  'black-bean-soup': 3.5276125743415463,
#  'bisques-cream-soups': 4.117552978808477,
#  'peanut-butter': 3.5561820378574307,
#  'greek': 4.3588571428571425,
#  'ethiopian': 3.4519725557461407,
#  'non-alcoholic': 3.554844216816048,
#  'a1-sauce': 3.545838614279679,
#  'main-dish-pork': 3.5395072217502124,
#  'pressure-cooker': 3.6436920596533655,
#  'irish': 3.8219178082191783,
#  'fillings-and-frostings-chocolate': 3.5530655391120507,
#  'snacks-kid-friendly': 3.5228161668839637,
#  'Throw the ultimate fiesta with this sopaipillas recipe from Food.com.': 3.5146321070234112,
#  'rosh-hashanah': 3.5234702430846605,
#  'lasagne': 3.528236316246742,
#  'austrian': 3.5598021582733814,
#  'black-beans': 3.933913731697665,
#  'nut-free': 3.586481947942905,
#  'chili': 3.891399128022196,
#  'smoothies': 3.4590856703803303,
#  'deep-fry': 4.016773162939297,
#  'baked-beans': 3.51890482398957,
#  'main-dish-beef': 3.478000854335754,
#  'cinco-de-mayo': 3.5860033726812817,
#  'simply-potatoes': 3.5812937062937062,
#  'canadian': 4.682430100103556,
#  'saudi-arabian': 3.4731088762571054,
#  'labor-day': 3.4634464751958225,
#  'yams-sweet-potatoes': 4.014206787687451,
#  'simply-potatoes2': 3.472185720543145,
#  'new-years': 4.453748006379585,
#  'elbow-macaroni': 4.04158255954784,
#  'grapes': 3.57991452991453,
#  'served-cold': 4.9416014449127035,
#  'pasta-rice-and-grains': 7.74161362463444,
#  'northeastern-united-states': 4.295427901524032,
#  'gelatin': 3.7835137385512074,
#  'mango': 3.7002028397565923,
#  'crab': 3.877999186661244,
#  'oranges': 3.9602132895816244,
#  'chowders': 3.9398222940226173,
#  'dairy-free': 3.5714872637633523,
#  'biscotti': 3.7474446337308347,
#  'polynesian': 3.562370493162039,
#  'oamc-freezer-make-ahead': 5.189568345323741,
#  'hunan': 3.538124452234882,
#  'lasagna': 4.004170141784821,
#  'desserts-easy': 3.4687774846086192,
#  'georgian': 3.518032786885246,
#  'deer': 3.6248919619706137,
#  'beef-liver': 3.489107219137121,
#  'beijing': 3.5919243986254297,
#  'puerto-rican': 3.5682113469034213,
#  'cauliflower': 3.8636363636363638,
#  'collard-greens': 3.552155172413793,
#  'meatloaf': 3.5656742556917687,
#  'african': 4.45474695234577,
#  'canning': 3.8790548658390067,
#  'barbecue': 4.551153978642783,
#  'scones': 3.745961227786753,
#  'less_thansql:name_topics_of_recipegreater_than': 3.478026533996683,
#  'baja': 3.580273270708796,
#  'quebec': 3.5317527519051652,
#  'tex-mex': 3.9796569605105705,
#  'beverages': 3.889125232650891,
#  'snacks-sweet': 3.444100751215201,
#  'toddler-friendly': 4.64131169709263,
#  'scandinavian': 3.9731785428342676,
#  'turkey-breasts': 3.650653181626633,
#  'crusts-pastry-dough-2': 3.724766751484309,
#  'ham': 4.096452770027899,
#  'chocolate-chip-cookies': 3.5195027861123016,
#  'fall': 5.468394989804835,
#  'indonesian': 3.577747378020976,
#  'stir-fry': 4.2232741617357,
#  'soul': 3.5077467906153164,
#  'dehydrator': 3.5335884353741496,
#  'smoker': 3.6133671742808797,
#  'pitted-fruit': 4.113229571984435,
#  'moroccan': 3.8582404917402995,
#  'coconut': 4.041021671826625,
#  'ham-and-bean-soup': 3.4967630556754425,
#  'cooking-mixes': 3.6506849315068495,
#  'stuffings-dressings': 3.8383838383838382,
#  'guatemalan': 3.4472128378378377,
#  'south-american': 3.9392286716010907,
#  'stews-poultry': 3.536720751494449,
#  'pork-loins-roast': 3.5047008547008547,
#  'salsas': 3.6261682242990654,
#  'pork-crock-pot': 3.529727313366115,
#  'hawaiian': 3.593448131037379,
#  'rosh-hashana': 3.648272957034541,
#  'welsh': 3.680561463207146}
